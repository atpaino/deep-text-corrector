# %%
from __future__ import print_function

import os
import time
import numpy as np
import tensorflow as tf
import pandas as pd
from collections import defaultdict

from sklearn.metrics import roc_auc_score, accuracy_score
import nltk

from correct_text import train, decode, decode_sentence, create_model, DefaultPTBConfig, DefaultMovieDialogConfig
from text_correcter_data_readers import PTBDataReader, MovieDialogReader
from text_correcter_models import InputBiasedNGramModel

# %matplotlib inline

# %%
root_data_path = "/Users/atpaino/data/textcorrecter/dialog_corpus"
train_path = os.path.join(root_data_path, "cleaned_dialog_train.txt")
val_path = os.path.join(root_data_path, "cleaned_dialog_val.txt")
test_path = os.path.join(root_data_path, "cleaned_dialog_test.txt")
model_path = os.path.join(root_data_path, "dialog_correcter_model")
config = DefaultMovieDialogConfig()

# %% [markdown]
# ## Train

# %%
data_reader = MovieDialogReader(config, train_path)

# %%
train(data_reader, train_path, val_path, model_path)
# Out:
# Reading data; train = /Users/atpaino/data/textcorrecter/dialog_corpus/cleaned_dialog_train.txt, test = /Users/atpaino/data/textcorrecter/dialog_corpus/cleaned_dialog_val.txt
# Creating 2 layers of 512 units.
# Created model with fresh parameters.
# Training bucket sizes: [226666, 98064, 56724, 80504]
# Total train size: 461958.0
# global step 100 learning rate 0.5000 step-time 4.61 perplexity 2143.50
#   eval: bucket 0 perplexity 220.79
#   eval: bucket 1 perplexity 340.07
#   eval: bucket 2 perplexity 390.61
#   eval: bucket 3 perplexity 604.10
# global step 200 learning rate 0.5000 step-time 4.27 perplexity 194.30
#   eval: bucket 0 perplexity 69.65
#   eval: bucket 1 perplexity 144.68
#   eval: bucket 2 perplexity 218.88
#   eval: bucket 3 perplexity 315.74
# global step 300 learning rate 0.5000 step-time 4.65 perplexity 94.97
#   eval: bucket 0 perplexity 30.62
#   eval: bucket 1 perplexity 97.79
#   eval: bucket 2 perplexity 158.51
#   eval: bucket 3 perplexity 225.04
# global step 400 learning rate 0.5000 step-time 4.30 perplexity 59.59
#   eval: bucket 0 perplexity 35.03
#   eval: bucket 1 perplexity 77.96
#   eval: bucket 2 perplexity 153.54
#   eval: bucket 3 perplexity 230.57
# global step 500 learning rate 0.5000 step-time 4.63 perplexity 48.56
#   eval: bucket 0 perplexity 14.60
#   eval: bucket 1 perplexity 57.95
#   eval: bucket 2 perplexity 92.62
#   eval: bucket 3 perplexity 156.89
# global step 600 learning rate 0.5000 step-time 4.92 perplexity 42.88
#   eval: bucket 0 perplexity 12.18
#   eval: bucket 1 perplexity 43.82
#   eval: bucket 2 perplexity 81.11
#   eval: bucket 3 perplexity 136.08
# global step 700 learning rate 0.5000 step-time 4.45 perplexity 28.37
#   eval: bucket 0 perplexity 9.72
#   eval: bucket 1 perplexity 33.79
#   eval: bucket 2 perplexity 63.79
#   eval: bucket 3 perplexity 113.24
# global step 800 learning rate 0.5000 step-time 4.27 perplexity 23.79
#   eval: bucket 0 perplexity 12.22
#   eval: bucket 1 perplexity 40.64
#   eval: bucket 2 perplexity 75.56
#   eval: bucket 3 perplexity 192.08
# global step 900 learning rate 0.5000 step-time 4.69 perplexity 22.31
#   eval: bucket 0 perplexity 7.51
#   eval: bucket 1 perplexity 19.66
#   eval: bucket 2 perplexity 38.43
#   eval: bucket 3 perplexity 71.74
# global step 1000 learning rate 0.5000 step-time 5.36 perplexity 23.69
#   eval: bucket 0 perplexity 6.15
#   eval: bucket 1 perplexity 20.09
#   eval: bucket 2 perplexity 40.03
#   eval: bucket 3 perplexity 71.64
# global step 1100 learning rate 0.5000 step-time 4.66 perplexity 15.36
#   eval: bucket 0 perplexity 7.44
#   eval: bucket 1 perplexity 17.61
#   eval: bucket 2 perplexity 26.96
#   eval: bucket 3 perplexity 64.98
# global step 1200 learning rate 0.5000 step-time 4.37 perplexity 11.92
#   eval: bucket 0 perplexity 5.41
#   eval: bucket 1 perplexity 12.69
#   eval: bucket 2 perplexity 22.34
#   eval: bucket 3 perplexity 42.59
# global step 1300 learning rate 0.5000 step-time 4.09 perplexity 9.09
#   eval: bucket 0 perplexity 4.10
#   eval: bucket 1 perplexity 9.80
#   eval: bucket 2 perplexity 12.40
#   eval: bucket 3 perplexity 30.64
# global step 1400 learning rate 0.5000 step-time 4.47 perplexity 9.36
#   eval: bucket 0 perplexity 4.04
#   eval: bucket 1 perplexity 8.30
#   eval: bucket 2 perplexity 13.71
#   eval: bucket 3 perplexity 25.00
# global step 1500 learning rate 0.5000 step-time 4.33 perplexity 7.29
#   eval: bucket 0 perplexity 4.89
#   eval: bucket 1 perplexity 12.74
#   eval: bucket 2 perplexity 32.55
#   eval: bucket 3 perplexity 58.86
# global step 1600 learning rate 0.5000 step-time 5.01 perplexity 7.06
#   eval: bucket 0 perplexity 3.61
#   eval: bucket 1 perplexity 5.55
#   eval: bucket 2 perplexity 9.90
#   eval: bucket 3 perplexity 17.77
# global step 1700 learning rate 0.5000 step-time 4.61 perplexity 5.72
#   eval: bucket 0 perplexity 3.38
#   eval: bucket 1 perplexity 5.92
#   eval: bucket 2 perplexity 7.01
#   eval: bucket 3 perplexity 14.54
# global step 1800 learning rate 0.5000 step-time 3.88 perplexity 5.09
#   eval: bucket 0 perplexity 2.72
#   eval: bucket 1 perplexity 7.05
#   eval: bucket 2 perplexity 8.28
#   eval: bucket 3 perplexity 17.11
# global step 1900 learning rate 0.5000 step-time 4.94 perplexity 4.62
#   eval: bucket 0 perplexity 2.80
#   eval: bucket 1 perplexity 3.60
#   eval: bucket 2 perplexity 5.02
#   eval: bucket 3 perplexity 7.50
# global step 2000 learning rate 0.5000 step-time 4.85 perplexity 4.95
#   eval: bucket 0 perplexity 2.87
#   eval: bucket 1 perplexity 4.94
#   eval: bucket 2 perplexity 8.27
#   eval: bucket 3 perplexity 17.86
# global step 2100 learning rate 0.5000 step-time 4.91 perplexity 3.80
#   eval: bucket 0 perplexity 2.57
#   eval: bucket 1 perplexity 3.37
#   eval: bucket 2 perplexity 4.70
#   eval: bucket 3 perplexity 19.56
# global step 2200 learning rate 0.5000 step-time 3.99 perplexity 3.41
#   eval: bucket 0 perplexity 2.22
#   eval: bucket 1 perplexity 4.11
#   eval: bucket 2 perplexity 7.91
#   eval: bucket 3 perplexity 18.71
# global step 2300 learning rate 0.5000 step-time 5.33 perplexity 3.93
#   eval: bucket 0 perplexity 2.42
#   eval: bucket 1 perplexity 2.85
#   eval: bucket 2 perplexity 3.56
#   eval: bucket 3 perplexity 5.09
# global step 2400 learning rate 0.5000 step-time 4.32 perplexity 2.79
#   eval: bucket 0 perplexity 2.00
#   eval: bucket 1 perplexity 3.24
#   eval: bucket 2 perplexity 3.91
#   eval: bucket 3 perplexity 5.02
# global step 2500 learning rate 0.5000 step-time 4.39 perplexity 2.98
#   eval: bucket 0 perplexity 1.68
#   eval: bucket 1 perplexity 3.37
#   eval: bucket 2 perplexity 3.78
#   eval: bucket 3 perplexity 5.11
# global step 2600 learning rate 0.5000 step-time 4.65 perplexity 2.96
#   eval: bucket 0 perplexity 1.94
#   eval: bucket 1 perplexity 3.08
#   eval: bucket 2 perplexity 3.32
#   eval: bucket 3 perplexity 4.78
# global step 2700 learning rate 0.5000 step-time 5.22 perplexity 3.14
#   eval: bucket 0 perplexity 1.89
#   eval: bucket 1 perplexity 2.82
#   eval: bucket 2 perplexity 3.35
#   eval: bucket 3 perplexity 4.38
# global step 2800 learning rate 0.4950 step-time 5.36 perplexity 2.71
#   eval: bucket 0 perplexity 2.25
#   eval: bucket 1 perplexity 5.05
#   eval: bucket 2 perplexity 7.86
#   eval: bucket 3 perplexity 16.90
# global step 2900 learning rate 0.4950 step-time 4.23 perplexity 2.35
#   eval: bucket 0 perplexity 2.01
#   eval: bucket 1 perplexity 2.65
#   eval: bucket 2 perplexity 3.06
#   eval: bucket 3 perplexity 3.99
# global step 3000 learning rate 0.4950 step-time 4.59 perplexity 2.34
#   eval: bucket 0 perplexity 1.56
#   eval: bucket 1 perplexity 2.07
#   eval: bucket 2 perplexity 3.13
#   eval: bucket 3 perplexity 3.77
# global step 3100 learning rate 0.4950 step-time 4.58 perplexity 2.41
#   eval: bucket 0 perplexity 1.67
#   eval: bucket 1 perplexity 2.31
#   eval: bucket 2 perplexity 3.16
#   eval: bucket 3 perplexity 4.88
# global step 3200 learning rate 0.4950 step-time 4.35 perplexity 2.23
#   eval: bucket 0 perplexity 1.72
#   eval: bucket 1 perplexity 2.10
#   eval: bucket 2 perplexity 2.79
#   eval: bucket 3 perplexity 2.96
# global step 3300 learning rate 0.4950 step-time 4.95 perplexity 2.40
#   eval: bucket 0 perplexity 1.72
#   eval: bucket 1 perplexity 2.19
#   eval: bucket 2 perplexity 2.74
#   eval: bucket 3 perplexity 2.94
# global step 3400 learning rate 0.4950 step-time 4.22 perplexity 2.11
#   eval: bucket 0 perplexity 1.50
#   eval: bucket 1 perplexity 1.93
#   eval: bucket 2 perplexity 2.48
#   eval: bucket 3 perplexity 3.42
# global step 3500 learning rate 0.4950 step-time 4.48 perplexity 2.39
#   eval: bucket 0 perplexity 1.67
#   eval: bucket 1 perplexity 2.93
#   eval: bucket 2 perplexity 5.00
#   eval: bucket 3 perplexity 18.43
# global step 3600 learning rate 0.4950 step-time 4.58 perplexity 2.44
#   eval: bucket 0 perplexity 1.57
#   eval: bucket 1 perplexity 2.02
#   eval: bucket 2 perplexity 2.38
#   eval: bucket 3 perplexity 3.28
# global step 3700 learning rate 0.4901 step-time 4.21 perplexity 1.96
#   eval: bucket 0 perplexity 1.53
#   eval: bucket 1 perplexity 2.13
#   eval: bucket 2 perplexity 2.37
#   eval: bucket 3 perplexity 3.70
# global step 3800 learning rate 0.4901 step-time 4.55 perplexity 2.13
#   eval: bucket 0 perplexity 1.45
#   eval: bucket 1 perplexity 2.01
#   eval: bucket 2 perplexity 2.74
#   eval: bucket 3 perplexity 2.75
# global step 3900 learning rate 0.4901 step-time 4.47 perplexity 1.89
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 1.86
#   eval: bucket 2 perplexity 1.89
#   eval: bucket 3 perplexity 2.62
# global step 4000 learning rate 0.4901 step-time 4.59 perplexity 2.03
#   eval: bucket 0 perplexity 1.54
#   eval: bucket 1 perplexity 2.66
#   eval: bucket 2 perplexity 7.95
#   eval: bucket 3 perplexity 24.42
# global step 4100 learning rate 0.4901 step-time 4.59 perplexity 2.15
#   eval: bucket 0 perplexity 1.82
#   eval: bucket 1 perplexity 1.89
#   eval: bucket 2 perplexity 2.09
#   eval: bucket 3 perplexity 2.50
# global step 4200 learning rate 0.4851 step-time 4.78 perplexity 1.89
#   eval: bucket 0 perplexity 1.47
#   eval: bucket 1 perplexity 1.90
#   eval: bucket 2 perplexity 2.32
#   eval: bucket 3 perplexity 3.64
# global step 4300 learning rate 0.4851 step-time 4.80 perplexity 2.45
#   eval: bucket 0 perplexity 1.66
#   eval: bucket 1 perplexity 2.38
#   eval: bucket 2 perplexity 2.30
#   eval: bucket 3 perplexity 3.64
# global step 4400 learning rate 0.4803 step-time 4.25 perplexity 2.11
#   eval: bucket 0 perplexity 1.60
#   eval: bucket 1 perplexity 1.99
#   eval: bucket 2 perplexity 2.44
#   eval: bucket 3 perplexity 3.75
# global step 4500 learning rate 0.4803 step-time 4.86 perplexity 1.80
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.78
#   eval: bucket 2 perplexity 2.36
#   eval: bucket 3 perplexity 2.84
# global step 4600 learning rate 0.4803 step-time 4.47 perplexity 1.74
#   eval: bucket 0 perplexity 1.51
#   eval: bucket 1 perplexity 1.77
#   eval: bucket 2 perplexity 2.16
#   eval: bucket 3 perplexity 2.68
# global step 4700 learning rate 0.4803 step-time 4.29 perplexity 1.88
#   eval: bucket 0 perplexity 1.51
#   eval: bucket 1 perplexity 2.27
#   eval: bucket 2 perplexity 2.45
#   eval: bucket 3 perplexity 2.85
# global step 4800 learning rate 0.4803 step-time 4.56 perplexity 1.73
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 1.83
#   eval: bucket 2 perplexity 2.10
#   eval: bucket 3 perplexity 2.45
# global step 4900 learning rate 0.4803 step-time 4.82 perplexity 1.70
#   eval: bucket 0 perplexity 5.90
#   eval: bucket 1 perplexity 3.56
#   eval: bucket 2 perplexity 3.19
#   eval: bucket 3 perplexity 5.04
# global step 5000 learning rate 0.4803 step-time 4.08 perplexity 1.92
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.64
#   eval: bucket 2 perplexity 2.08
#   eval: bucket 3 perplexity 4.41
# global step 5100 learning rate 0.4755 step-time 4.57 perplexity 2.02
#   eval: bucket 0 perplexity 1.46
#   eval: bucket 1 perplexity 2.30
#   eval: bucket 2 perplexity 2.35
#   eval: bucket 3 perplexity 4.77
# global step 5200 learning rate 0.4707 step-time 4.77 perplexity 2.00
#   eval: bucket 0 perplexity 1.40
#   eval: bucket 1 perplexity 1.58
#   eval: bucket 2 perplexity 2.17
#   eval: bucket 3 perplexity 3.92
# global step 5300 learning rate 0.4707 step-time 4.77 perplexity 1.87
#   eval: bucket 0 perplexity 1.44
#   eval: bucket 1 perplexity 1.66
#   eval: bucket 2 perplexity 2.20
#   eval: bucket 3 perplexity 3.38
# global step 5400 learning rate 0.4707 step-time 4.83 perplexity 1.92
#   eval: bucket 0 perplexity 1.35
#   eval: bucket 1 perplexity 1.73
#   eval: bucket 2 perplexity 2.28
#   eval: bucket 3 perplexity 3.59
# global step 5500 learning rate 0.4707 step-time 4.88 perplexity 2.17
#   eval: bucket 0 perplexity 1.49
#   eval: bucket 1 perplexity 1.62
#   eval: bucket 2 perplexity 1.97
#   eval: bucket 3 perplexity 4.51
# global step 5600 learning rate 0.4660 step-time 4.36 perplexity 2.01
#   eval: bucket 0 perplexity 1.47
#   eval: bucket 1 perplexity 1.86
#   eval: bucket 2 perplexity 2.63
#   eval: bucket 3 perplexity 15.62
# global step 5700 learning rate 0.4660 step-time 4.54 perplexity 2.16
#   eval: bucket 0 perplexity 1.46
#   eval: bucket 1 perplexity 1.69
#   eval: bucket 2 perplexity 2.29
#   eval: bucket 3 perplexity 6.21
# global step 5800 learning rate 0.4660 step-time 4.64 perplexity 2.76
#   eval: bucket 0 perplexity 1.42
#   eval: bucket 1 perplexity 1.58
#   eval: bucket 2 perplexity 2.63
#   eval: bucket 3 perplexity 20.59
# global step 5900 learning rate 0.4614 step-time 5.23 perplexity 3.63
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 2.53
#   eval: bucket 2 perplexity 10.80
#   eval: bucket 3 perplexity 48.46
# global step 6000 learning rate 0.4568 step-time 5.27 perplexity 5.12
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 2.04
#   eval: bucket 2 perplexity 4.76
#   eval: bucket 3 perplexity 25.74
# global step 6100 learning rate 0.4522 step-time 4.57 perplexity 3.11
#   eval: bucket 0 perplexity 1.32
#   eval: bucket 1 perplexity 2.38
#   eval: bucket 2 perplexity 10.10
#   eval: bucket 3 perplexity 49.92
# global step 6200 learning rate 0.4522 step-time 4.72 perplexity 3.24
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.72
#   eval: bucket 2 perplexity 2.95
#   eval: bucket 3 perplexity 23.02
# global step 6300 learning rate 0.4522 step-time 4.85 perplexity 3.41
#   eval: bucket 0 perplexity 2.04
#   eval: bucket 1 perplexity 6.31
#   eval: bucket 2 perplexity 12.94
#   eval: bucket 3 perplexity 31.21
# global step 6400 learning rate 0.4522 step-time 4.42 perplexity 3.20
#   eval: bucket 0 perplexity 3.70
#   eval: bucket 1 perplexity 11.29
#   eval: bucket 2 perplexity 10.95
#   eval: bucket 3 perplexity 43.46
# global step 6500 learning rate 0.4522 step-time 4.29 perplexity 2.95
#   eval: bucket 0 perplexity 1.44
#   eval: bucket 1 perplexity 2.50
#   eval: bucket 2 perplexity 7.06
#   eval: bucket 3 perplexity 46.87
# global step 6600 learning rate 0.4522 step-time 4.79 perplexity 3.23
#   eval: bucket 0 perplexity 1.44
#   eval: bucket 1 perplexity 2.07
#   eval: bucket 2 perplexity 3.93
#   eval: bucket 3 perplexity 35.24
# global step 6700 learning rate 0.4522 step-time 4.42 perplexity 2.84
#   eval: bucket 0 perplexity 1.44
#   eval: bucket 1 perplexity 2.03
#   eval: bucket 2 perplexity 3.92
#   eval: bucket 3 perplexity 31.83
# global step 6800 learning rate 0.4522 step-time 4.27 perplexity 2.82
#   eval: bucket 0 perplexity 1.37
#   eval: bucket 1 perplexity 2.24
#   eval: bucket 2 perplexity 5.33
#   eval: bucket 3 perplexity 32.98
# global step 6900 learning rate 0.4522 step-time 5.21 perplexity 4.85
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 2.42
#   eval: bucket 2 perplexity 13.36
#   eval: bucket 3 perplexity 60.65
# global step 7000 learning rate 0.4477 step-time 4.45 perplexity 4.44
#   eval: bucket 0 perplexity 1.43
#   eval: bucket 1 perplexity 2.79
#   eval: bucket 2 perplexity 9.37
#   eval: bucket 3 perplexity 52.71
# global step 7100 learning rate 0.4477 step-time 4.66 perplexity 5.38
#   eval: bucket 0 perplexity 1.65
#   eval: bucket 1 perplexity 3.78
#   eval: bucket 2 perplexity 7.59
#   eval: bucket 3 perplexity 39.86
# global step 7200 learning rate 0.4432 step-time 5.05 perplexity 4.36
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 3.37
#   eval: bucket 2 perplexity 31.19
#   eval: bucket 3 perplexity 124.52
# global step 7300 learning rate 0.4432 step-time 4.54 perplexity 3.91
#   eval: bucket 0 perplexity 1.54
#   eval: bucket 1 perplexity 4.39
#   eval: bucket 2 perplexity 7.60
#   eval: bucket 3 perplexity 29.69
# global step 7400 learning rate 0.4432 step-time 5.22 perplexity 4.72
#   eval: bucket 0 perplexity 1.63
#   eval: bucket 1 perplexity 4.15
#   eval: bucket 2 perplexity 15.33
#   eval: bucket 3 perplexity 52.54
# global step 7500 learning rate 0.4432 step-time 4.66 perplexity 3.63
#   eval: bucket 0 perplexity 1.54
#   eval: bucket 1 perplexity 2.60
#   eval: bucket 2 perplexity 7.93
#   eval: bucket 3 perplexity 38.66
# global step 7600 learning rate 0.4432 step-time 5.05 perplexity 3.84
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 2.67
#   eval: bucket 2 perplexity 4.04
#   eval: bucket 3 perplexity 15.19
# global step 7700 learning rate 0.4432 step-time 4.94 perplexity 3.45
#   eval: bucket 0 perplexity 1.76
#   eval: bucket 1 perplexity 3.19
#   eval: bucket 2 perplexity 4.81
#   eval: bucket 3 perplexity 16.01
# global step 7800 learning rate 0.4432 step-time 4.95 perplexity 3.00
#   eval: bucket 0 perplexity 1.48
#   eval: bucket 1 perplexity 1.96
#   eval: bucket 2 perplexity 3.05
#   eval: bucket 3 perplexity 10.96
# global step 7900 learning rate 0.4432 step-time 4.23 perplexity 2.12
#   eval: bucket 0 perplexity 1.62
#   eval: bucket 1 perplexity 1.90
#   eval: bucket 2 perplexity 2.55
#   eval: bucket 3 perplexity 6.45
# global step 8000 learning rate 0.4432 step-time 4.77 perplexity 2.26
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.69
#   eval: bucket 2 perplexity 2.44
#   eval: bucket 3 perplexity 7.68
# global step 8100 learning rate 0.4432 step-time 4.64 perplexity 2.02
#   eval: bucket 0 perplexity 1.45
#   eval: bucket 1 perplexity 1.61
#   eval: bucket 2 perplexity 2.21
#   eval: bucket 3 perplexity 5.30
# global step 8200 learning rate 0.4432 step-time 4.59 perplexity 2.11
#   eval: bucket 0 perplexity 1.31
#   eval: bucket 1 perplexity 1.68
#   eval: bucket 2 perplexity 2.23
#   eval: bucket 3 perplexity 4.92
# global step 8300 learning rate 0.4432 step-time 4.39 perplexity 1.87
#   eval: bucket 0 perplexity 1.45
#   eval: bucket 1 perplexity 1.67
#   eval: bucket 2 perplexity 3.13
#   eval: bucket 3 perplexity 7.19
# global step 8400 learning rate 0.4432 step-time 4.03 perplexity 1.81
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.70
#   eval: bucket 2 perplexity 2.36
#   eval: bucket 3 perplexity 6.97
# global step 8500 learning rate 0.4432 step-time 5.00 perplexity 2.07
#   eval: bucket 0 perplexity 1.31
#   eval: bucket 1 perplexity 2.09
#   eval: bucket 2 perplexity 2.37
#   eval: bucket 3 perplexity 5.44
# global step 8600 learning rate 0.4432 step-time 5.14 perplexity 2.12
#   eval: bucket 0 perplexity 1.41
#   eval: bucket 1 perplexity 1.63
#   eval: bucket 2 perplexity 2.73
#   eval: bucket 3 perplexity 7.58
# global step 8700 learning rate 0.4388 step-time 4.31 perplexity 1.74
#   eval: bucket 0 perplexity 1.31
#   eval: bucket 1 perplexity 1.64
#   eval: bucket 2 perplexity 2.16
#   eval: bucket 3 perplexity 4.10
# global step 8800 learning rate 0.4388 step-time 4.85 perplexity 1.74
#   eval: bucket 0 perplexity 1.31
#   eval: bucket 1 perplexity 1.63
#   eval: bucket 2 perplexity 1.66
#   eval: bucket 3 perplexity 4.09
# global step 8900 learning rate 0.4388 step-time 4.12 perplexity 1.64
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 1.60
#   eval: bucket 2 perplexity 2.34
#   eval: bucket 3 perplexity 6.82
# global step 9000 learning rate 0.4388 step-time 4.83 perplexity 1.75
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 1.44
#   eval: bucket 2 perplexity 2.08
#   eval: bucket 3 perplexity 3.30
# global step 9100 learning rate 0.4344 step-time 4.37 perplexity 1.63
#   eval: bucket 0 perplexity 1.34
#   eval: bucket 1 perplexity 1.70
#   eval: bucket 2 perplexity 1.69
#   eval: bucket 3 perplexity 3.32
# global step 9200 learning rate 0.4344 step-time 4.47 perplexity 1.53
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 1.66
#   eval: bucket 2 perplexity 1.83
#   eval: bucket 3 perplexity 3.91
# global step 9300 learning rate 0.4344 step-time 4.22 perplexity 1.48
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.43
#   eval: bucket 2 perplexity 1.70
#   eval: bucket 3 perplexity 2.61
# global step 9400 learning rate 0.4344 step-time 4.58 perplexity 1.52
#   eval: bucket 0 perplexity 1.27
#   eval: bucket 1 perplexity 1.44
#   eval: bucket 2 perplexity 1.69
#   eval: bucket 3 perplexity 2.46
# global step 9500 learning rate 0.4344 step-time 4.57 perplexity 1.55
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.44
#   eval: bucket 2 perplexity 1.73
#   eval: bucket 3 perplexity 2.81
# global step 9600 learning rate 0.4300 step-time 4.88 perplexity 1.51
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.37
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 2.36
# global step 9700 learning rate 0.4300 step-time 4.01 perplexity 1.33
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.43
#   eval: bucket 3 perplexity 2.17
# global step 9800 learning rate 0.4300 step-time 4.38 perplexity 1.44
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.54
#   eval: bucket 3 perplexity 3.44
# global step 9900 learning rate 0.4300 step-time 4.47 perplexity 1.36
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.38
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 3.63
# global step 10000 learning rate 0.4300 step-time 5.35 perplexity 1.59
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.33
#   eval: bucket 2 perplexity 1.53
#   eval: bucket 3 perplexity 2.26
# global step 10100 learning rate 0.4257 step-time 5.22 perplexity 1.51
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.61
#   eval: bucket 3 perplexity 1.93
# global step 10200 learning rate 0.4257 step-time 4.93 perplexity 1.39
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.39
#   eval: bucket 2 perplexity 1.46
#   eval: bucket 3 perplexity 1.77
# global step 10300 learning rate 0.4257 step-time 5.07 perplexity 1.35
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.86
# global step 10400 learning rate 0.4257 step-time 4.63 perplexity 1.32
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.45
#   eval: bucket 3 perplexity 1.64
# global step 10500 learning rate 0.4257 step-time 18.82 perplexity 1.39
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 1.85
# global step 10600 learning rate 0.4257 step-time 5.23 perplexity 1.57
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.29
#   eval: bucket 2 perplexity 1.70
#   eval: bucket 3 perplexity 1.84
# global step 10700 learning rate 0.4215 step-time 4.28 perplexity 1.49
#   eval: bucket 0 perplexity 1.31
#   eval: bucket 1 perplexity 1.33
#   eval: bucket 2 perplexity 3.40
#   eval: bucket 3 perplexity 4.71
# global step 10800 learning rate 0.4215 step-time 4.69 perplexity 1.58
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.50
#   eval: bucket 3 perplexity 2.61
# global step 10900 learning rate 0.4173 step-time 4.63 perplexity 1.45
#   eval: bucket 0 perplexity 1.31
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.46
#   eval: bucket 3 perplexity 1.87
# global step 11000 learning rate 0.4173 step-time 4.16 perplexity 1.34
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 1.87
# global step 11100 learning rate 0.4173 step-time 4.12 perplexity 1.34
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.42
#   eval: bucket 2 perplexity 1.57
#   eval: bucket 3 perplexity 2.48
# global step 11200 learning rate 0.4173 step-time 4.82 perplexity 1.35
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.44
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 1.69
# global step 11300 learning rate 0.4173 step-time 4.22 perplexity 1.28
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.53
#   eval: bucket 2 perplexity 1.63
#   eval: bucket 3 perplexity 2.00
# global step 11400 learning rate 0.4173 step-time 4.16 perplexity 1.31
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 3.19
# global step 11500 learning rate 0.4173 step-time 4.37 perplexity 1.31
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.41
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 1.91
# global step 11600 learning rate 0.4173 step-time 4.65 perplexity 1.29
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.82
# global step 11700 learning rate 0.4173 step-time 4.15 perplexity 1.25
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.35
#   eval: bucket 2 perplexity 1.38
#   eval: bucket 3 perplexity 1.94
# global step 11800 learning rate 0.4173 step-time 4.33 perplexity 1.25
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 1.67
# global step 11900 learning rate 0.4173 step-time 4.21 perplexity 1.26
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 1.53
# global step 12000 learning rate 0.4173 step-time 4.68 perplexity 1.29
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.36
#   eval: bucket 3 perplexity 1.57
# global step 12100 learning rate 0.4131 step-time 4.90 perplexity 1.34
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 2.00
# global step 12200 learning rate 0.4090 step-time 4.22 perplexity 1.24
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.53
# global step 12300 learning rate 0.4090 step-time 4.08 perplexity 1.22
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.77
# global step 12400 learning rate 0.4090 step-time 4.30 perplexity 1.23
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.55
#   eval: bucket 3 perplexity 2.20
# global step 12500 learning rate 0.4090 step-time 4.18 perplexity 1.24
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.86
# global step 12600 learning rate 0.4049 step-time 4.18 perplexity 1.23
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.40
#   eval: bucket 3 perplexity 1.58
# global step 12700 learning rate 0.4049 step-time 4.95 perplexity 1.24
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.62
# global step 12800 learning rate 0.4008 step-time 4.81 perplexity 1.23
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.51
# global step 12900 learning rate 0.4008 step-time 4.46 perplexity 1.25
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.49
# global step 13000 learning rate 0.3968 step-time 4.17 perplexity 1.21
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.40
# global step 13100 learning rate 0.3968 step-time 4.25 perplexity 1.23
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 2.10
# global step 13200 learning rate 0.3968 step-time 4.62 perplexity 1.32
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.69
#   eval: bucket 3 perplexity 3.80
# global step 13300 learning rate 0.3928 step-time 5.00 perplexity 1.24
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.47
# global step 13400 learning rate 0.3928 step-time 4.69 perplexity 1.22
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 1.39
# global step 13500 learning rate 0.3928 step-time 4.25 perplexity 1.20
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.54
# global step 13600 learning rate 0.3928 step-time 4.76 perplexity 1.20
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.39
# global step 13700 learning rate 0.3928 step-time 5.05 perplexity 1.19
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.39
# global step 13800 learning rate 0.3928 step-time 4.57 perplexity 1.17
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.47
# global step 13900 learning rate 0.3928 step-time 4.39 perplexity 1.17
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.40
# global step 14000 learning rate 0.3928 step-time 4.89 perplexity 1.19
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.33
# global step 14100 learning rate 0.3889 step-time 4.05 perplexity 1.14
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.32
# global step 14200 learning rate 0.3889 step-time 4.82 perplexity 1.17
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.43
# global step 14300 learning rate 0.3889 step-time 5.45 perplexity 1.25
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 2.09
# global step 14400 learning rate 0.3850 step-time 4.45 perplexity 1.17
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.60
#   eval: bucket 3 perplexity 3.24
# global step 14500 learning rate 0.3850 step-time 5.01 perplexity 1.20
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.35
# global step 14600 learning rate 0.3850 step-time 4.45 perplexity 1.16
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.44
# global step 14700 learning rate 0.3850 step-time 4.76 perplexity 1.16
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.27
# global step 14800 learning rate 0.3850 step-time 4.36 perplexity 1.14
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.40
# global step 14900 learning rate 0.3850 step-time 4.58 perplexity 1.14
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.25
# global step 15000 learning rate 0.3850 step-time 4.29 perplexity 1.21
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 3.58
# global step 15100 learning rate 0.3812 step-time 4.00 perplexity 1.24
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.99
# global step 15200 learning rate 0.3774 step-time 4.75 perplexity 1.28
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.65
# global step 15300 learning rate 0.3736 step-time 4.82 perplexity 1.19
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.34
# global step 15400 learning rate 0.3736 step-time 4.83 perplexity 1.15
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.34
# global step 15500 learning rate 0.3736 step-time 4.87 perplexity 1.15
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.33
# global step 15600 learning rate 0.3736 step-time 4.67 perplexity 1.14
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 1.33
# global step 15700 learning rate 0.3736 step-time 5.22 perplexity 1.22
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.64
# global step 15800 learning rate 0.3699 step-time 4.67 perplexity 1.16
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.36
# global step 15900 learning rate 0.3699 step-time 4.45 perplexity 1.30
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 2.68
# global step 16000 learning rate 0.3662 step-time 4.78 perplexity 1.26
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.50
# global step 16100 learning rate 0.3662 step-time 4.53 perplexity 1.18
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.40
# global step 16200 learning rate 0.3662 step-time 4.46 perplexity 1.17
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.28
# global step 16300 learning rate 0.3662 step-time 4.81 perplexity 1.17
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 5.81
# global step 16400 learning rate 0.3662 step-time 5.06 perplexity 1.21
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.42
# global step 16500 learning rate 0.3625 step-time 4.15 perplexity 1.12
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.28
# global step 16600 learning rate 0.3625 step-time 4.40 perplexity 1.13
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.46
# global step 16700 learning rate 0.3625 step-time 4.45 perplexity 1.13
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.29
# global step 16800 learning rate 0.3625 step-time 4.67 perplexity 1.13
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.33
# global step 16900 learning rate 0.3625 step-time 4.92 perplexity 1.15
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.19
# global step 17000 learning rate 0.3589 step-time 4.51 perplexity 1.18
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 1.39
# global step 17100 learning rate 0.3553 step-time 4.63 perplexity 1.20
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 2.55
# global step 17200 learning rate 0.3517 step-time 4.43 perplexity 1.24
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.77
# global step 17300 learning rate 0.3482 step-time 4.66 perplexity 1.21
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.33
# global step 17400 learning rate 0.3482 step-time 5.58 perplexity 1.17
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.39
# global step 17500 learning rate 0.3482 step-time 4.93 perplexity 1.17
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.57
# global step 17600 learning rate 0.3482 step-time 4.19 perplexity 1.13
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.27
# global step 17700 learning rate 0.3482 step-time 4.06 perplexity 1.14
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.57
# global step 17800 learning rate 0.3482 step-time 4.87 perplexity 1.15
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.12
#   eval: bucket 3 perplexity 1.39
# global step 17900 learning rate 0.3482 step-time 5.09 perplexity 1.15
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.49
# global step 18000 learning rate 0.3447 step-time 4.87 perplexity 1.18
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 1.48
# global step 18100 learning rate 0.3413 step-time 5.03 perplexity 1.16
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.10
#   eval: bucket 3 perplexity 1.25
# global step 18200 learning rate 0.3413 step-time 4.49 perplexity 1.11
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.34
# global step 18300 learning rate 0.3413 step-time 4.28 perplexity 1.12
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.37
# global step 18400 learning rate 0.3413 step-time 4.79 perplexity 1.13
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.28
# global step 18500 learning rate 0.3413 step-time 4.55 perplexity 1.14
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.23
# global step 18600 learning rate 0.3379 step-time 4.84 perplexity 1.12
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.23
# global step 18700 learning rate 0.3379 step-time 4.67 perplexity 1.11
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.18
# global step 18800 learning rate 0.3379 step-time 4.81 perplexity 1.12
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.08
#   eval: bucket 3 perplexity 1.22
# global step 18900 learning rate 0.3379 step-time 4.31 perplexity 1.11
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.30
# global step 19000 learning rate 0.3379 step-time 4.61 perplexity 1.10
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.10
#   eval: bucket 3 perplexity 1.23
# global step 19100 learning rate 0.3379 step-time 5.12 perplexity 1.10
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.08
#   eval: bucket 2 perplexity 1.13
#   eval: bucket 3 perplexity 1.17
# global step 19200 learning rate 0.3379 step-time 4.24 perplexity 1.09
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.20
# global step 19300 learning rate 0.3379 step-time 4.35 perplexity 1.09
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.12
#   eval: bucket 3 perplexity 1.17
# global step 19400 learning rate 0.3379 step-time 5.15 perplexity 1.10
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.19
# global step 19500 learning rate 0.3379 step-time 4.78 perplexity 1.11
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.07
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.21
# global step 19600 learning rate 0.3345 step-time 4.73 perplexity 1.10
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.09
#   eval: bucket 3 perplexity 1.22
# global step 19700 learning rate 0.3345 step-time 4.69 perplexity 1.10
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.10
#   eval: bucket 3 perplexity 1.22
# global step 19800 learning rate 0.3345 step-time 5.06 perplexity 1.10
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.20
# global step 19900 learning rate 0.3345 step-time 3.97 perplexity 1.08
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.14
#   eval: bucket 3 perplexity 1.24
# global step 20000 learning rate 0.3345 step-time 4.39 perplexity 1.09
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.08
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.17

# %% [markdown]
# ## Decode sentences

# %%
data_reader = MovieDialogReader(config, train_path, dropout_prob=0.25, replacement_prob=0.25, dataset_copies=1)

# %%
ngram_model = InputBiasedNGramModel(data_reader, train_path)

# %%
ngram_model.prob("hello", [], ["hello", "friend"])
# Out:
# 0.800534625413185

# %%
ngram_model.prob("friend", [], ["hello", "friend"])
# Out:
# 0.3200131397951014

# %%
ngram_model.prob("friend", ["hello"], ["hello", "friend"])
# Out:
# 0.8

# %%
sess = tf.InteractiveSession()
model = create_model(sess, True, model_path, config=config)
# Out:
# Reading model parameters from /Users/atpaino/data/textcorrecter/dialog_corpus/dialog_correcter_model/translate.ckpt-20000

# %%
# Test a sample from the test dataset.
decoded = decode_sentence(sess, model, data_reader, "you have girlfriend", ngram_model=ngram_model)
# Out:
# adj prob of she is 19.5401934555, orig prob is 19.5385818481
# adj prob of to is 19.8772380668, orig prob is 19.8767967224
# adj prob of for is 19.9113501505, orig prob is 19.9108562469
# adj prob of of is 19.6186662088, orig prob is 19.617980957
# adj prob of 've is 20.2236632214, orig prob is 20.2235832214
# adj prob of have is 23.7042996892, orig prob is 23.4905319214
# adj prob of you is 45.0243129319, orig prob is 44.2111854553
# adj prob of we is 22.7613260914, orig prob is 22.7578716278
# adj prob of they is 21.8396258412, orig prob is 21.8379173279
# adj prob of i is 25.0736176086, orig prob is 25.0479240417
# Using token you
# adj prob of shall is 12.1456444127, orig prob is 12.1455154419
# adj prob of the is 13.0883536896, orig prob is 13.0876674652
# adj prob of used is 12.3276011519, orig prob is 12.327372551
# adj prob of must is 13.7987719708, orig prob is 13.7976112366
# adj prob of a is 13.773842809, orig prob is 13.7722835541
# adj prob of do is 12.6965355754, orig prob is 12.6890964508
# adj prob of got is 15.2239086963, orig prob is 15.2207536697
# adj prob of 've is 17.0885138355, orig prob is 17.0845870972
# adj prob of 'll is 18.9412182896, orig prob is 18.9380531311
# adj prob of have is 28.2103300185, orig prob is 27.4056777954
# Using token have
# adj prob of dan is 6.00970209702, orig prob is 6.00962209702
# adj prob of -more- is 6.07458914383, orig prob is 6.07450914383
# adj prob of an is 10.0125135428, orig prob is 10.0104446411
# adj prob of girlfriend is 8.8484085083, orig prob is 8.0484085083
# adj prob of rose is 6.10450781448, orig prob is 6.10442781448
# adj prob of suspicious is 7.85185612305, orig prob is 7.85177612305
# adj prob of my is 6.07588090175, orig prob is 6.07455921173
# adj prob of unhappy is 7.20402229889, orig prob is 7.20394229889
# adj prob of the is 11.5175824307, orig prob is 11.5105028152
# adj prob of a is 13.9888325418, orig prob is 13.964632988
# Using token a
# adj prob of son is 6.63286281806, orig prob is 6.63259410858
# adj prob of queen is 6.72252459977, orig prob is 6.72240543365
# adj prob of impression is 6.81991852386, orig prob is 6.81983852386
# adj prob of tab is 6.77727796619, orig prob is 6.7771730423
# adj prob of fifth is 6.85266547551, orig prob is 6.85256767273
# adj prob of girlfriend is 10.3632834943, orig prob is 10.1498184204
# adj prob of suspicious is 7.16727125129, orig prob is 7.16718769073
# adj prob of list is 8.64421153984, orig prob is 8.64399623871
# adj prob of unhappy is 6.94649494751, orig prob is 6.94641494751
# adj prob of favorites is 6.94003189667, orig prob is 6.93995189667
# Using token girlfriend
# Input: you have girlfriend
# Output: you have a girlfriend

# %%
decoded = decode_sentence(sess, model, data_reader, "blablahblah went to the market", ngram_model=ngram_model)
# Out:
# adj prob of very is 7.40181912493, orig prob is 7.40153217316
# adj prob of even is 7.53177624196, orig prob is 7.53161001205
# adj prob of 's is 9.45088200842, orig prob is 9.45079708099
# adj prob of one is 8.95518184077, orig prob is 8.95480537415
# adj prob of 'll is 7.55581034286, orig prob is 7.55573034286
# adj prob of his is 8.7218195339, orig prob is 8.72158432007
# adj prob of an is 13.3071738617, orig prob is 13.3069534302
# adj prob of the is 17.3503058683, orig prob is 17.2191810608
# adj prob of a is 15.3809703451, orig prob is 15.3795566559
# adj prob of blablahblah is 24.165336391, orig prob is 23.365316391
# Using token blablahblah
# adj prob of vision is 10.2649544583, orig prob is 10.2648744583
# adj prob of 've is 10.3702906476, orig prob is 10.3702106476
# adj prob of aware is 10.7392138348, orig prob is 10.7391338348
# adj prob of followed is 12.1530560361, orig prob is 12.1529760361
# adj prob of the is 10.9985148697, orig prob is 10.8705148697
# adj prob of about is 10.7583865033, orig prob is 10.7583065033
# adj prob of 's is 14.9889019833, orig prob is 14.9888219833
# adj prob of drove is 10.4054030286, orig prob is 10.4053230286
# adj prob of blablahblah is 12.2350966449, orig prob is 12.1070766449
# adj prob of went is 23.7423656464, orig prob is 22.9423656464
# Using token went
# adj prob of for is 13.9350496996, orig prob is 13.9314842224
# adj prob of of is 13.9588574277, orig prob is 13.9587774277
# adj prob of he is 14.31780995, orig prob is 14.31772995
# adj prob of a is 14.38035488, orig prob is 14.3797769547
# adj prob of 's is 15.5454100476, orig prob is 15.5453300476
# adj prob of in is 15.8451430786, orig prob is 15.8412456512
# adj prob of the is 17.0645311384, orig prob is 16.9361991882
# adj prob of you is 16.5838202344, orig prob is 16.5837402344
# adj prob of we is 16.6009692417, orig prob is 16.6007232666
# adj prob of to is 28.9609605705, orig prob is 28.1017074585
# Using token to
# adj prob of 's is 7.33340872391, orig prob is 7.33332872391
# adj prob of all is 7.39524645146, orig prob is 7.39494419098
# adj prob of market is 8.1396344118, orig prob is 8.01162815094
# adj prob of a is 14.6922730741, orig prob is 14.6898765564
# adj prob of an is 14.0472162372, orig prob is 14.0469264984
# adj prob of on is 8.38901998143, orig prob is 8.38892745972
# adj prob of in is 10.8423637662, orig prob is 10.8422555923
# adj prob of EOS is 10.8494976593, orig prob is 10.8493976593
# adj prob of your is 8.06698213771, orig prob is 8.06507396698
# adj prob of the is 24.0948436854, orig prob is 23.2845821381
# Using token the
# adj prob of fittest is 6.49933851678, orig prob is 6.49925088882
# adj prob of native is 6.68526686295, orig prob is 6.68518686295
# adj prob of puppy is 6.6888316961, orig prob is 6.68874406815
# adj prob of mustache is 6.75830289689, orig prob is 6.75821781158
# adj prob of center is 6.70577831445, orig prob is 6.70560932159
# adj prob of package is 6.83225191122, orig prob is 6.83214139938
# adj prob of nerd is 7.26000695443, orig prob is 7.25992441177
# adj prob of minute- is 7.42448652847, orig prob is 7.42440652847
# adj prob of -� is 7.48598326309, orig prob is 7.48590326309
# adj prob of market is 10.2431222127, orig prob is 9.44304084778
# Using token market
# Input: UNK went to the market
# Output: blablahblah went to the market

# %%
decoded = decode_sentence(sess, model, data_reader, "blablahblah went to whatsit", ngram_model=ngram_model)
# Out:
# adj prob of 's is 7.99116807256, orig prob is 7.99108314514
# adj prob of me is 8.13354595829, orig prob is 8.13318920135
# adj prob of blablahblah is 26.1398732867, orig prob is 25.3398532867
# adj prob of 'll is 8.18633164032, orig prob is 8.18625164032
# adj prob of even is 10.0410826728, orig prob is 10.0409164429
# adj prob of the is 16.1783909647, orig prob is 16.1751861572
# adj prob of a is 15.1742242437, orig prob is 15.1728105545
# adj prob of an is 13.0255385773, orig prob is 13.0253181458
# adj prob of one is 9.22195887935, orig prob is 9.22158241272
# adj prob of his is 9.48717178304, orig prob is 9.48693656921
# Using token blablahblah
# adj prob of an is 10.1539954053, orig prob is 10.1539154053
# adj prob of drove is 10.3940276013, orig prob is 10.3939476013
# adj prob of a is 10.324884306, orig prob is 10.324804306
# adj prob of covered is 10.5649632321, orig prob is 10.5648832321
# adj prob of blablahblah is 10.9269086185, orig prob is 10.7668886185
# adj prob of the is 10.6831196652, orig prob is 10.6830396652
# adj prob of me is 10.8048037396, orig prob is 10.8047237396
# adj prob of went is 22.1684310913, orig prob is 21.3684310913
# adj prob of followed is 12.2268360959, orig prob is 12.2267560959
# adj prob of 's is 14.6457537518, orig prob is 14.6456737518
# Using token went
# adj prob of 've is 11.9615076886, orig prob is 11.9614276886
# adj prob of i is 12.1696986066, orig prob is 12.1696186066
# adj prob of the is 12.3941897975, orig prob is 12.3937778473
# adj prob of of is 13.8179892407, orig prob is 13.8179092407
# adj prob of you is 14.3633421765, orig prob is 14.3632621765
# adj prob of we is 13.8619193302, orig prob is 13.8616733551
# adj prob of his is 14.1105288373, orig prob is 14.1104488373
# adj prob of a is 14.8204555498, orig prob is 14.8198776245
# adj prob of to is 27.4762060082, orig prob is 26.6169528961
# adj prob of 's is 14.3841122495, orig prob is 14.3840322495
# Using token to
# adj prob of innocent is 6.97445477112, orig prob is 6.97437477112
# adj prob of brilliant is 6.99171675308, orig prob is 6.99163675308
# adj prob of bachelor is 7.20490349396, orig prob is 7.20482349396
# adj prob of dawn is 7.03033081872, orig prob is 7.03024768829
# adj prob of goal is 7.28962648972, orig prob is 7.28954648972
# adj prob of a is 8.22356885047, orig prob is 8.22117233276
# adj prob of the is 8.76185216749, orig prob is 8.75151062012
# adj prob of minute- is 7.70389116867, orig prob is 7.70381116867
# adj prob of extra is 7.31446732147, orig prob is 7.31438732147
# adj prob of i- is 8.11216057404, orig prob is 8.11208057404
# Using token the
# adj prob of superintendent is 7.57596211504, orig prob is 7.57587194443
# adj prob of son is 7.66811612241, orig prob is 7.66792678833
# adj prob of quote is 7.783100178, orig prob is 7.78301763535
# adj prob of extra is 8.62643103096, orig prob is 8.62631034851
# adj prob of cellar is 8.2003560507, orig prob is 8.20024299622
# adj prob of bachelor is 8.5435103255, orig prob is 8.54341506958
# adj prob of goal is 8.81637752826, orig prob is 8.81628227234
# adj prob of wine is 8.23610166282, orig prob is 8.23594284058
# adj prob of source is 7.85856584425, orig prob is 7.85841464996
# adj prob of minute- is 9.7496680127, orig prob is 9.7495880127
# Using token minute-
# Input: UNK went to whatsit
# Output: blablahblah went to the minute-

# %%
blah = decode_str("do you have book")
# Out:
# Input: do you have book
# Output: do you have a book

# %%
def decode_str(s):
    return decode_sentence(sess, model, data_reader, s)

# %%
def decode_sentence(sess, model, data_reader, sentence, verbose=True):
    """Used with InteractiveSession in an IPython notebook."""
    return next(decode(sess, model, data_reader, [sentence.split()], verbose))

# %%
# Dropout and replacement rates of 0.9

# %%
# Build corpus and decode hypotheses.
baseline_hypotheses = defaultdict(list)  # The model's input
model_hypotheses = defaultdict(list)  # The actual model's predictions
targets = defaultdict(list)
blah = 0

for source, target in data_reader.read_samples_by_string(test_path):
    
    matching_buckets = [i for i, bucket in enumerate(model.buckets) if len(source) < bucket[0]]
    if not matching_buckets:
        continue
    bucket_id = matching_buckets[0]
    
    model_hypotheses[bucket_id].append(next(decode(sess, model, data_reader, [source], verbose=False)))
    
    # Replace out of vocab words with "UNK" in the baseline hypothesis to make it a little fairer.
    baseline_hypothesis = [word if word in data_reader.token_to_id else MovieDialogReader.UNKNOWN_TOKEN
                           for word in source]
    baseline_hypotheses[bucket_id].append(baseline_hypothesis)
    
    # nltk.corpus_bleu expects a list of one or more reference tranlsations per sample,
    # so we wrap the target list in another list here.
    targets[bucket_id].append([target])
    
#     blah += 1
#     if blah > 10:
#         break

# %%
for bucket_id in targets.keys():
    baseline_bleu_score = nltk.translate.bleu_score.corpus_bleu(targets[bucket_id], baseline_hypotheses[bucket_id])
    model_bleu_score = nltk.translate.bleu_score.corpus_bleu(targets[bucket_id], model_hypotheses[bucket_id])
    print("Bucket {}: {}".format(bucket_id, model.buckets[bucket_id]))
    print("\tBaseline BLEU = {}\n\tModel BLEU = {}".format(baseline_bleu_score, model_bleu_score))
# Out:
# Bucket 0: (10, 10)
# 	Baseline BLEU = 0.671113372091
# 	Model BLEU = 0.662576018437
# Bucket 1: (15, 15)
# 	Baseline BLEU = 0.724487231051
# 	Model BLEU = 0.695375017816
# Bucket 2: (20, 20)
# 	Baseline BLEU = 0.750923521318
# 	Model BLEU = 0.72081720851
# Bucket 3: (40, 40)
# 	Baseline BLEU = 0.77119960248
# 	Model BLEU = 0.712245139018
