# %%
from __future__ import print_function

import os
import time
import numpy as np
import tensorflow as tf
import pandas as pd
from collections import defaultdict

from sklearn.metrics import roc_auc_score, accuracy_score
import nltk

from correct_text import train, decode, create_model, DefaultConfig, DefaultMovieDialogConfig
from text_correcter_model import PTBDataReader, MovieDialogReader

# %matplotlib inline

# %%
root_data_path = "/Users/atpaino/data/textcorrecter/dialog_corpus"
train_path = os.path.join(root_data_path, "cleaned_dialog_train.txt")#"ptb.train.txt") 
val_path = os.path.join(root_data_path, "cleaned_dialog_val.txt")#"ptb.valid.txt")
test_path = os.path.join(root_data_path, "cleaned_dialog_test.txt")
model_path = os.path.join(root_data_path, "dialog_correcter_model")
config = DefaultConfig()

# %% [markdown]
# ## Train

# %%
data_reader = MovieDialogReader(config, train_path)

# %%
train(data_reader, train_path, val_path, model_path)
# Out:
# Reading PTB data; train = /Users/atpaino/data/textcorrecter/dialog_corpus/cleaned_dialog_train.txt, test = /Users/atpaino/data/textcorrecter/dialog_corpus/cleaned_dialog_val.txt
# Creating 2 layers of 512 units.
# Created model with fresh parameters.
# Training bucket sizes: [113333, 49032, 28362, 40252]
# Total train size: 230979.0
# global step 100 learning rate 0.5000 step-time 8.62 perplexity 1746.50
#   eval: bucket 0 perplexity 59.71
#   eval: bucket 1 perplexity 234.62
#   eval: bucket 2 perplexity 265.53
#   eval: bucket 3 perplexity 308.15
# global step 200 learning rate 0.5000 step-time 3.87 perplexity 92.27
#   eval: bucket 0 perplexity 39.02
#   eval: bucket 1 perplexity 175.45
#   eval: bucket 2 perplexity 184.19
#   eval: bucket 3 perplexity 222.94
# global step 300 learning rate 0.5000 step-time 4.37 perplexity 78.92
#   eval: bucket 0 perplexity 15.84
#   eval: bucket 1 perplexity 79.16
#   eval: bucket 2 perplexity 112.48
#   eval: bucket 3 perplexity 144.01
# global step 400 learning rate 0.5000 step-time 3.70 perplexity 44.55
#   eval: bucket 0 perplexity 10.90
#   eval: bucket 1 perplexity 42.22
#   eval: bucket 2 perplexity 73.96
#   eval: bucket 3 perplexity 146.01
# global step 500 learning rate 0.5000 step-time 3.17 perplexity 31.34
#   eval: bucket 0 perplexity 17.48
#   eval: bucket 1 perplexity 95.62
#   eval: bucket 2 perplexity 92.81
#   eval: bucket 3 perplexity 151.41
# global step 600 learning rate 0.5000 step-time 3.84 perplexity 27.11
#   eval: bucket 0 perplexity 9.27
#   eval: bucket 1 perplexity 27.94
#   eval: bucket 2 perplexity 52.48
#   eval: bucket 3 perplexity 101.02
# global step 700 learning rate 0.5000 step-time 3.35 perplexity 24.07
#   eval: bucket 0 perplexity 6.96
#   eval: bucket 1 perplexity 23.29
#   eval: bucket 2 perplexity 46.24
#   eval: bucket 3 perplexity 93.22
# global step 800 learning rate 0.5000 step-time 3.86 perplexity 17.30
#   eval: bucket 0 perplexity 5.43
#   eval: bucket 1 perplexity 20.93
#   eval: bucket 2 perplexity 36.89
#   eval: bucket 3 perplexity 72.60
# global step 900 learning rate 0.5000 step-time 3.65 perplexity 15.49
#   eval: bucket 0 perplexity 5.67
#   eval: bucket 1 perplexity 17.93
#   eval: bucket 2 perplexity 34.78
#   eval: bucket 3 perplexity 66.83
# global step 1000 learning rate 0.5000 step-time 4.18 perplexity 13.96
#   eval: bucket 0 perplexity 3.83
#   eval: bucket 1 perplexity 15.02
#   eval: bucket 2 perplexity 26.00
#   eval: bucket 3 perplexity 68.21
# global step 1100 learning rate 0.5000 step-time 3.54 perplexity 10.49
#   eval: bucket 0 perplexity 3.78
#   eval: bucket 1 perplexity 12.26
#   eval: bucket 2 perplexity 22.33
#   eval: bucket 3 perplexity 56.61
# global step 1200 learning rate 0.5000 step-time 3.08 perplexity 8.43
#   eval: bucket 0 perplexity 3.32
#   eval: bucket 1 perplexity 10.70
#   eval: bucket 2 perplexity 18.19
#   eval: bucket 3 perplexity 45.62
# global step 1300 learning rate 0.5000 step-time 4.35 perplexity 9.92
#   eval: bucket 0 perplexity 4.69
#   eval: bucket 1 perplexity 13.51
#   eval: bucket 2 perplexity 18.65
#   eval: bucket 3 perplexity 42.44
# global step 1400 learning rate 0.5000 step-time 4.15 perplexity 9.42
#   eval: bucket 0 perplexity 2.48
#   eval: bucket 1 perplexity 8.39
#   eval: bucket 2 perplexity 15.42
#   eval: bucket 3 perplexity 37.08
# global step 1500 learning rate 0.5000 step-time 3.14 perplexity 5.64
#   eval: bucket 0 perplexity 2.63
#   eval: bucket 1 perplexity 7.08
#   eval: bucket 2 perplexity 12.79
#   eval: bucket 3 perplexity 32.14
# global step 1600 learning rate 0.5000 step-time 3.93 perplexity 6.72
#   eval: bucket 0 perplexity 2.54
#   eval: bucket 1 perplexity 8.24
#   eval: bucket 2 perplexity 18.83
#   eval: bucket 3 perplexity 49.76
# global step 1700 learning rate 0.5000 step-time 3.41 perplexity 5.50
#   eval: bucket 0 perplexity 2.75
#   eval: bucket 1 perplexity 4.89
#   eval: bucket 2 perplexity 11.74
#   eval: bucket 3 perplexity 27.73
# global step 1800 learning rate 0.5000 step-time 3.31 perplexity 5.12
#   eval: bucket 0 perplexity 3.59
#   eval: bucket 1 perplexity 10.12
#   eval: bucket 2 perplexity 14.09
#   eval: bucket 3 perplexity 34.50
# global step 1900 learning rate 0.5000 step-time 3.79 perplexity 5.59
#   eval: bucket 0 perplexity 2.03
#   eval: bucket 1 perplexity 5.02
#   eval: bucket 2 perplexity 11.12
#   eval: bucket 3 perplexity 27.47
# global step 2000 learning rate 0.5000 step-time 3.26 perplexity 4.48
#   eval: bucket 0 perplexity 2.07
#   eval: bucket 1 perplexity 5.11
#   eval: bucket 2 perplexity 9.45
#   eval: bucket 3 perplexity 22.93
# global step 2100 learning rate 0.5000 step-time 3.47 perplexity 4.48
#   eval: bucket 0 perplexity 2.15
#   eval: bucket 1 perplexity 4.01
#   eval: bucket 2 perplexity 8.25
#   eval: bucket 3 perplexity 21.41
# global step 2200 learning rate 0.5000 step-time 4.22 perplexity 5.16
#   eval: bucket 0 perplexity 2.38
#   eval: bucket 1 perplexity 4.40
#   eval: bucket 2 perplexity 8.20
#   eval: bucket 3 perplexity 18.38
# global step 2300 learning rate 0.5000 step-time 4.19 perplexity 4.95
#   eval: bucket 0 perplexity 2.27
#   eval: bucket 1 perplexity 4.32
#   eval: bucket 2 perplexity 7.94
#   eval: bucket 3 perplexity 15.52
# global step 2400 learning rate 0.5000 step-time 3.55 perplexity 3.96
#   eval: bucket 0 perplexity 1.97
#   eval: bucket 1 perplexity 3.96
#   eval: bucket 2 perplexity 7.60
#   eval: bucket 3 perplexity 22.27
# global step 2500 learning rate 0.5000 step-time 3.11 perplexity 3.36
#   eval: bucket 0 perplexity 1.95
#   eval: bucket 1 perplexity 4.03
#   eval: bucket 2 perplexity 6.90
#   eval: bucket 3 perplexity 14.91
# global step 2600 learning rate 0.5000 step-time 3.81 perplexity 3.91
#   eval: bucket 0 perplexity 1.66
#   eval: bucket 1 perplexity 3.64
#   eval: bucket 2 perplexity 6.80
#   eval: bucket 3 perplexity 16.02
# global step 2700 learning rate 0.5000 step-time 3.65 perplexity 3.34
#   eval: bucket 0 perplexity 1.54
#   eval: bucket 1 perplexity 3.27
#   eval: bucket 2 perplexity 6.05
#   eval: bucket 3 perplexity 14.80
# global step 2800 learning rate 0.5000 step-time 3.71 perplexity 3.29
#   eval: bucket 0 perplexity 1.72
#   eval: bucket 1 perplexity 3.63
#   eval: bucket 2 perplexity 5.39
#   eval: bucket 3 perplexity 14.56
# global step 2900 learning rate 0.5000 step-time 3.47 perplexity 3.08
#   eval: bucket 0 perplexity 1.81
#   eval: bucket 1 perplexity 3.41
#   eval: bucket 2 perplexity 7.29
#   eval: bucket 3 perplexity 16.96
# global step 3000 learning rate 0.5000 step-time 3.78 perplexity 3.39
#   eval: bucket 0 perplexity 1.66
#   eval: bucket 1 perplexity 2.96
#   eval: bucket 2 perplexity 6.22
#   eval: bucket 3 perplexity 13.01
# global step 3100 learning rate 0.4950 step-time 3.91 perplexity 3.32
#   eval: bucket 0 perplexity 1.69
#   eval: bucket 1 perplexity 2.68
#   eval: bucket 2 perplexity 4.78
#   eval: bucket 3 perplexity 12.10
# global step 3200 learning rate 0.4950 step-time 3.82 perplexity 3.23
#   eval: bucket 0 perplexity 1.44
#   eval: bucket 1 perplexity 3.15
#   eval: bucket 2 perplexity 4.37
#   eval: bucket 3 perplexity 12.34
# global step 3300 learning rate 0.4950 step-time 3.07 perplexity 2.44
#   eval: bucket 0 perplexity 1.66
#   eval: bucket 1 perplexity 2.36
#   eval: bucket 2 perplexity 5.27
#   eval: bucket 3 perplexity 12.06
# global step 3400 learning rate 0.4950 step-time 4.25 perplexity 3.61
#   eval: bucket 0 perplexity 1.66
#   eval: bucket 1 perplexity 2.89
#   eval: bucket 2 perplexity 4.57
#   eval: bucket 3 perplexity 11.57
# global step 3500 learning rate 0.4901 step-time 3.41 perplexity 2.53
#   eval: bucket 0 perplexity 1.86
#   eval: bucket 1 perplexity 2.24
#   eval: bucket 2 perplexity 4.96
#   eval: bucket 3 perplexity 9.59
# global step 3600 learning rate 0.4901 step-time 3.34 perplexity 2.54
#   eval: bucket 0 perplexity 1.52
#   eval: bucket 1 perplexity 2.31
#   eval: bucket 2 perplexity 4.24
#   eval: bucket 3 perplexity 11.14
# global step 3700 learning rate 0.4901 step-time 3.65 perplexity 2.49
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 2.70
#   eval: bucket 2 perplexity 4.61
#   eval: bucket 3 perplexity 11.25
# global step 3800 learning rate 0.4901 step-time 3.74 perplexity 2.61
#   eval: bucket 0 perplexity 1.51
#   eval: bucket 1 perplexity 2.06
#   eval: bucket 2 perplexity 3.55
#   eval: bucket 3 perplexity 9.12
# global step 3900 learning rate 0.4851 step-time 3.16 perplexity 2.17
#   eval: bucket 0 perplexity 1.41
#   eval: bucket 1 perplexity 2.41
#   eval: bucket 2 perplexity 3.52
#   eval: bucket 3 perplexity 10.13
# global step 4000 learning rate 0.4851 step-time 3.40 perplexity 2.32
#   eval: bucket 0 perplexity 1.62
#   eval: bucket 1 perplexity 2.59
#   eval: bucket 2 perplexity 4.25
#   eval: bucket 3 perplexity 13.01
# global step 4100 learning rate 0.4851 step-time 3.91 perplexity 2.62
#   eval: bucket 0 perplexity 1.34
#   eval: bucket 1 perplexity 2.53
#   eval: bucket 2 perplexity 4.02
#   eval: bucket 3 perplexity 11.54
# global step 4200 learning rate 0.4803 step-time 3.40 perplexity 2.29
#   eval: bucket 0 perplexity 1.33
#   eval: bucket 1 perplexity 2.09
#   eval: bucket 2 perplexity 3.62
#   eval: bucket 3 perplexity 9.55
# global step 4300 learning rate 0.4803 step-time 3.77 perplexity 2.45
#   eval: bucket 0 perplexity 1.50
#   eval: bucket 1 perplexity 2.22
#   eval: bucket 2 perplexity 4.43
#   eval: bucket 3 perplexity 9.93
# global step 4400 learning rate 0.4803 step-time 3.77 perplexity 2.31
#   eval: bucket 0 perplexity 1.48
#   eval: bucket 1 perplexity 2.13
#   eval: bucket 2 perplexity 3.87
#   eval: bucket 3 perplexity 9.31
# global step 4500 learning rate 0.4803 step-time 4.02 perplexity 2.50
#   eval: bucket 0 perplexity 1.44
#   eval: bucket 1 perplexity 2.26
#   eval: bucket 2 perplexity 3.83
#   eval: bucket 3 perplexity 9.27
# global step 4600 learning rate 0.4755 step-time 2.99 perplexity 1.82
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 2.34
#   eval: bucket 2 perplexity 3.27
#   eval: bucket 3 perplexity 9.46
# global step 4700 learning rate 0.4755 step-time 3.29 perplexity 2.02
#   eval: bucket 0 perplexity 1.29
#   eval: bucket 1 perplexity 1.93
#   eval: bucket 2 perplexity 3.08
#   eval: bucket 3 perplexity 7.66
# global step 4800 learning rate 0.4755 step-time 3.38 perplexity 2.00
#   eval: bucket 0 perplexity 1.54
#   eval: bucket 1 perplexity 2.20
#   eval: bucket 2 perplexity 3.49
#   eval: bucket 3 perplexity 8.19
# global step 4900 learning rate 0.4755 step-time 4.22 perplexity 2.18
#   eval: bucket 0 perplexity 1.38
#   eval: bucket 1 perplexity 1.99
#   eval: bucket 2 perplexity 3.00
#   eval: bucket 3 perplexity 7.76
# global step 5000 learning rate 0.4707 step-time 3.44 perplexity 1.94
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.87
#   eval: bucket 2 perplexity 3.11
#   eval: bucket 3 perplexity 6.63
# global step 5100 learning rate 0.4707 step-time 3.56 perplexity 2.09
#   eval: bucket 0 perplexity 1.39
#   eval: bucket 1 perplexity 1.79
#   eval: bucket 2 perplexity 2.67
#   eval: bucket 3 perplexity 6.92
# global step 5200 learning rate 0.4707 step-time 3.64 perplexity 1.98
#   eval: bucket 0 perplexity 1.38
#   eval: bucket 1 perplexity 2.06
#   eval: bucket 2 perplexity 3.70
#   eval: bucket 3 perplexity 13.17
# global step 5300 learning rate 0.4707 step-time 3.28 perplexity 1.78
#   eval: bucket 0 perplexity 1.37
#   eval: bucket 1 perplexity 1.93
#   eval: bucket 2 perplexity 3.11
#   eval: bucket 3 perplexity 7.96
# global step 5400 learning rate 0.4707 step-time 3.52 perplexity 2.02
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.90
#   eval: bucket 2 perplexity 2.62
#   eval: bucket 3 perplexity 6.61
# global step 5500 learning rate 0.4707 step-time 3.73 perplexity 1.89
#   eval: bucket 0 perplexity 1.29
#   eval: bucket 1 perplexity 1.76
#   eval: bucket 2 perplexity 3.61
#   eval: bucket 3 perplexity 9.06
# global step 5600 learning rate 0.4707 step-time 3.78 perplexity 2.21
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.79
#   eval: bucket 2 perplexity 2.70
#   eval: bucket 3 perplexity 6.23
# global step 5700 learning rate 0.4660 step-time 3.13 perplexity 1.70
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.80
#   eval: bucket 2 perplexity 2.59
#   eval: bucket 3 perplexity 5.43
# global step 5800 learning rate 0.4660 step-time 3.70 perplexity 1.90
#   eval: bucket 0 perplexity 1.44
#   eval: bucket 1 perplexity 1.69
#   eval: bucket 2 perplexity 2.41
#   eval: bucket 3 perplexity 5.58
# global step 5900 learning rate 0.4660 step-time 3.78 perplexity 1.90
#   eval: bucket 0 perplexity 1.29
#   eval: bucket 1 perplexity 1.76
#   eval: bucket 2 perplexity 2.74
#   eval: bucket 3 perplexity 5.29
# global step 6000 learning rate 0.4660 step-time 3.53 perplexity 1.80
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 2.13
#   eval: bucket 2 perplexity 3.78
#   eval: bucket 3 perplexity 8.49
# global step 6100 learning rate 0.4660 step-time 4.68 perplexity 2.20
#   eval: bucket 0 perplexity 1.36
#   eval: bucket 1 perplexity 1.66
#   eval: bucket 2 perplexity 2.56
#   eval: bucket 3 perplexity 5.83
# global step 6200 learning rate 0.4614 step-time 3.88 perplexity 1.82
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.72
#   eval: bucket 2 perplexity 2.58
#   eval: bucket 3 perplexity 5.88
# global step 6300 learning rate 0.4614 step-time 3.55 perplexity 1.77
#   eval: bucket 0 perplexity 1.32
#   eval: bucket 1 perplexity 1.63
#   eval: bucket 2 perplexity 2.38
#   eval: bucket 3 perplexity 5.51
# global step 6400 learning rate 0.4614 step-time 3.86 perplexity 1.85
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.59
#   eval: bucket 2 perplexity 2.07
#   eval: bucket 3 perplexity 5.15
# global step 6500 learning rate 0.4614 step-time 3.55 perplexity 1.66
#   eval: bucket 0 perplexity 1.40
#   eval: bucket 1 perplexity 1.54
#   eval: bucket 2 perplexity 2.63
#   eval: bucket 3 perplexity 5.79
# global step 6600 learning rate 0.4614 step-time 3.70 perplexity 1.77
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.58
#   eval: bucket 2 perplexity 2.36
#   eval: bucket 3 perplexity 5.01
# global step 6700 learning rate 0.4614 step-time 4.28 perplexity 1.93
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.69
#   eval: bucket 2 perplexity 2.52
#   eval: bucket 3 perplexity 9.12
# global step 6800 learning rate 0.4568 step-time 3.35 perplexity 1.56
#   eval: bucket 0 perplexity 1.31
#   eval: bucket 1 perplexity 1.73
#   eval: bucket 2 perplexity 3.30
#   eval: bucket 3 perplexity 7.75
# global step 6900 learning rate 0.4568 step-time 4.16 perplexity 1.88
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.45
#   eval: bucket 2 perplexity 2.14
#   eval: bucket 3 perplexity 5.78
# global step 7000 learning rate 0.4568 step-time 4.07 perplexity 1.76
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.53
#   eval: bucket 2 perplexity 2.09
#   eval: bucket 3 perplexity 4.50
# global step 7100 learning rate 0.4568 step-time 3.40 perplexity 1.56
#   eval: bucket 0 perplexity 1.24
#   eval: bucket 1 perplexity 1.47
#   eval: bucket 2 perplexity 2.61
#   eval: bucket 3 perplexity 5.06
# global step 7200 learning rate 0.4568 step-time 3.71 perplexity 1.66
#   eval: bucket 0 perplexity 1.23
#   eval: bucket 1 perplexity 1.62
#   eval: bucket 2 perplexity 2.12
#   eval: bucket 3 perplexity 3.83
# global step 7300 learning rate 0.4568 step-time 3.68 perplexity 1.64
#   eval: bucket 0 perplexity 1.25
#   eval: bucket 1 perplexity 1.72
#   eval: bucket 2 perplexity 2.03
#   eval: bucket 3 perplexity 4.81
# global step 7400 learning rate 0.4568 step-time 3.50 perplexity 1.63
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.53
#   eval: bucket 2 perplexity 2.03
#   eval: bucket 3 perplexity 5.42
# global step 7500 learning rate 0.4568 step-time 4.35 perplexity 1.84
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.51
#   eval: bucket 2 perplexity 2.49
#   eval: bucket 3 perplexity 5.17
# global step 7600 learning rate 0.4522 step-time 3.70 perplexity 1.59
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.54
#   eval: bucket 2 perplexity 1.95
#   eval: bucket 3 perplexity 3.57
# global step 7700 learning rate 0.4522 step-time 3.36 perplexity 1.52
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.58
#   eval: bucket 2 perplexity 2.12
#   eval: bucket 3 perplexity 5.47
# global step 7800 learning rate 0.4522 step-time 3.30 perplexity 1.53
#   eval: bucket 0 perplexity 1.22
#   eval: bucket 1 perplexity 1.56
#   eval: bucket 2 perplexity 2.39
#   eval: bucket 3 perplexity 5.66
# global step 7900 learning rate 0.4522 step-time 4.11 perplexity 1.73
#   eval: bucket 0 perplexity 1.28
#   eval: bucket 1 perplexity 1.53
#   eval: bucket 2 perplexity 2.60
#   eval: bucket 3 perplexity 6.04
# global step 8000 learning rate 0.4477 step-time 3.50 perplexity 1.49
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.50
#   eval: bucket 2 perplexity 1.69
#   eval: bucket 3 perplexity 4.58
# global step 8100 learning rate 0.4477 step-time 3.47 perplexity 1.49
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.51
#   eval: bucket 2 perplexity 2.18
#   eval: bucket 3 perplexity 5.80
# global step 8200 learning rate 0.4477 step-time 3.66 perplexity 1.55
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.35
#   eval: bucket 2 perplexity 1.94
#   eval: bucket 3 perplexity 4.78
# global step 8300 learning rate 0.4477 step-time 3.42 perplexity 1.49
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.44
#   eval: bucket 2 perplexity 2.01
#   eval: bucket 3 perplexity 4.27
# global step 8400 learning rate 0.4477 step-time 3.39 perplexity 1.44
#   eval: bucket 0 perplexity 1.26
#   eval: bucket 1 perplexity 1.46
#   eval: bucket 2 perplexity 2.01
#   eval: bucket 3 perplexity 4.03
# global step 8500 learning rate 0.4477 step-time 3.53 perplexity 1.50
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.51
#   eval: bucket 2 perplexity 1.98
#   eval: bucket 3 perplexity 4.01
# global step 8600 learning rate 0.4477 step-time 2.96 perplexity 1.34
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.48
#   eval: bucket 2 perplexity 1.77
#   eval: bucket 3 perplexity 3.66
# global step 8700 learning rate 0.4477 step-time 4.52 perplexity 2.15
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.45
#   eval: bucket 2 perplexity 1.98
#   eval: bucket 3 perplexity 4.30
# global step 8800 learning rate 0.4432 step-time 3.48 perplexity 1.46
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.40
#   eval: bucket 2 perplexity 1.84
#   eval: bucket 3 perplexity 4.27
# global step 8900 learning rate 0.4432 step-time 4.20 perplexity 1.62
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.37
#   eval: bucket 2 perplexity 1.73
#   eval: bucket 3 perplexity 3.66
# global step 9000 learning rate 0.4432 step-time 3.53 perplexity 1.41
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.50
#   eval: bucket 2 perplexity 1.63
#   eval: bucket 3 perplexity 3.88
# global step 9100 learning rate 0.4432 step-time 3.87 perplexity 1.52
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.40
#   eval: bucket 2 perplexity 1.88
#   eval: bucket 3 perplexity 3.38
# global step 9200 learning rate 0.4432 step-time 2.91 perplexity 1.30
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.38
#   eval: bucket 2 perplexity 1.86
#   eval: bucket 3 perplexity 3.45
# global step 9300 learning rate 0.4432 step-time 3.55 perplexity 1.43
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.80
#   eval: bucket 3 perplexity 4.13
# global step 9400 learning rate 0.4432 step-time 3.49 perplexity 1.37
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.49
#   eval: bucket 2 perplexity 1.95
#   eval: bucket 3 perplexity 4.61
# global step 9500 learning rate 0.4432 step-time 3.63 perplexity 1.43
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.82
#   eval: bucket 3 perplexity 3.26
# global step 9600 learning rate 0.4388 step-time 3.21 perplexity 1.36
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.65
#   eval: bucket 3 perplexity 3.51
# global step 9700 learning rate 0.4388 step-time 3.26 perplexity 1.33
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.82
#   eval: bucket 3 perplexity 3.59
# global step 9800 learning rate 0.4388 step-time 3.21 perplexity 1.35
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.77
#   eval: bucket 3 perplexity 3.70
# global step 9900 learning rate 0.4388 step-time 4.07 perplexity 1.52
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.71
#   eval: bucket 3 perplexity 3.64
# global step 10000 learning rate 0.4344 step-time 3.37 perplexity 1.34
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.37
#   eval: bucket 2 perplexity 1.82
#   eval: bucket 3 perplexity 3.87
# global step 10100 learning rate 0.4344 step-time 4.05 perplexity 1.55
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.87
#   eval: bucket 3 perplexity 3.38
# global step 10200 learning rate 0.4300 step-time 3.84 perplexity 1.43
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.34
#   eval: bucket 2 perplexity 1.69
#   eval: bucket 3 perplexity 3.38
# global step 10300 learning rate 0.4300 step-time 3.38 perplexity 1.34
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.29
#   eval: bucket 2 perplexity 1.60
#   eval: bucket 3 perplexity 3.43
# global step 10400 learning rate 0.4300 step-time 3.65 perplexity 1.38
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.74
#   eval: bucket 3 perplexity 3.23
# global step 10500 learning rate 0.4300 step-time 3.28 perplexity 1.33
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.60
#   eval: bucket 3 perplexity 3.33
# global step 10600 learning rate 0.4300 step-time 3.89 perplexity 1.44
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.59
#   eval: bucket 3 perplexity 3.51
# global step 10700 learning rate 0.4257 step-time 3.41 perplexity 1.31
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.34
#   eval: bucket 2 perplexity 2.10
#   eval: bucket 3 perplexity 3.79
# global step 10800 learning rate 0.4257 step-time 3.85 perplexity 1.38
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.69
#   eval: bucket 3 perplexity 3.51
# global step 10900 learning rate 0.4257 step-time 3.50 perplexity 1.33
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.61
#   eval: bucket 3 perplexity 3.43
# global step 11000 learning rate 0.4257 step-time 4.35 perplexity 1.52
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.69
#   eval: bucket 3 perplexity 3.62
# global step 11100 learning rate 0.4215 step-time 3.34 perplexity 1.28
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.62
#   eval: bucket 3 perplexity 3.30
# global step 11200 learning rate 0.4215 step-time 4.16 perplexity 1.48
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.61
#   eval: bucket 3 perplexity 3.62
# global step 11300 learning rate 0.4215 step-time 4.54 perplexity 1.49
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.83
#   eval: bucket 3 perplexity 3.41
# global step 11400 learning rate 0.4215 step-time 3.38 perplexity 1.28
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.69
#   eval: bucket 3 perplexity 2.82
# global step 11500 learning rate 0.4215 step-time 3.69 perplexity 1.31
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.56
#   eval: bucket 3 perplexity 3.06
# global step 11600 learning rate 0.4215 step-time 3.85 perplexity 1.83
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.39
#   eval: bucket 2 perplexity 1.95
#   eval: bucket 3 perplexity 5.76
# global step 11700 learning rate 0.4173 step-time 3.79 perplexity 1.37
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.55
#   eval: bucket 3 perplexity 2.97
# global step 11800 learning rate 0.4173 step-time 3.70 perplexity 1.38
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.66
#   eval: bucket 3 perplexity 3.88
# global step 11900 learning rate 0.4173 step-time 3.85 perplexity 1.36
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.64
#   eval: bucket 3 perplexity 3.47
# global step 12000 learning rate 0.4173 step-time 3.28 perplexity 1.24
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.43
#   eval: bucket 3 perplexity 2.74
# global step 12100 learning rate 0.4173 step-time 4.03 perplexity 1.41
#   eval: bucket 0 perplexity 1.19
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.68
#   eval: bucket 3 perplexity 3.24
# global step 12200 learning rate 0.4131 step-time 4.10 perplexity 1.37
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.29
#   eval: bucket 2 perplexity 1.58
#   eval: bucket 3 perplexity 3.28
# global step 12300 learning rate 0.4131 step-time 3.60 perplexity 1.32
#   eval: bucket 0 perplexity 1.18
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.48
#   eval: bucket 3 perplexity 2.84
# global step 12400 learning rate 0.4131 step-time 3.66 perplexity 1.29
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.59
#   eval: bucket 3 perplexity 2.62
# global step 12500 learning rate 0.4131 step-time 3.69 perplexity 1.28
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.60
#   eval: bucket 3 perplexity 3.35
# global step 12600 learning rate 0.4131 step-time 3.18 perplexity 1.25
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.52
#   eval: bucket 3 perplexity 3.06
# global step 12700 learning rate 0.4131 step-time 4.03 perplexity 1.32
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.56
#   eval: bucket 3 perplexity 2.98
# global step 12800 learning rate 0.4090 step-time 3.48 perplexity 1.25
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.51
#   eval: bucket 3 perplexity 2.95
# global step 12900 learning rate 0.4090 step-time 2.94 perplexity 1.18
#   eval: bucket 0 perplexity 1.21
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.47
#   eval: bucket 3 perplexity 2.90
# global step 13000 learning rate 0.4090 step-time 3.66 perplexity 1.26
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.48
#   eval: bucket 3 perplexity 3.06
# global step 13100 learning rate 0.4090 step-time 3.27 perplexity 1.28
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.29
#   eval: bucket 2 perplexity 1.92
#   eval: bucket 3 perplexity 4.26
# global step 13200 learning rate 0.4049 step-time 3.50 perplexity 1.24
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.53
#   eval: bucket 3 perplexity 2.89
# global step 13300 learning rate 0.4049 step-time 4.03 perplexity 1.39
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.49
#   eval: bucket 2 perplexity 2.10
#   eval: bucket 3 perplexity 5.35
# global step 13400 learning rate 0.4008 step-time 4.17 perplexity 1.36
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.35
#   eval: bucket 2 perplexity 1.89
#   eval: bucket 3 perplexity 5.39
# global step 13500 learning rate 0.4008 step-time 3.12 perplexity 1.19
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.48
#   eval: bucket 3 perplexity 2.91
# global step 13600 learning rate 0.4008 step-time 3.83 perplexity 1.27
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.43
#   eval: bucket 3 perplexity 3.14
# global step 13700 learning rate 0.4008 step-time 3.80 perplexity 1.27
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.44
#   eval: bucket 3 perplexity 2.98
# global step 13800 learning rate 0.4008 step-time 3.61 perplexity 1.34
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.62
#   eval: bucket 3 perplexity 3.18
# global step 13900 learning rate 0.3968 step-time 3.91 perplexity 1.32
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.64
#   eval: bucket 3 perplexity 2.88
# global step 14000 learning rate 0.3968 step-time 3.34 perplexity 1.21
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.49
#   eval: bucket 3 perplexity 2.39
# global step 14100 learning rate 0.3968 step-time 3.92 perplexity 1.31
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 2.57
# global step 14200 learning rate 0.3968 step-time 3.26 perplexity 1.19
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.56
#   eval: bucket 3 perplexity 3.37
# global step 14300 learning rate 0.3968 step-time 3.23 perplexity 1.19
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 2.57
# global step 14400 learning rate 0.3968 step-time 4.09 perplexity 1.35
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 3.17
# global step 14500 learning rate 0.3928 step-time 3.84 perplexity 1.28
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 2.88
# global step 14600 learning rate 0.3928 step-time 3.64 perplexity 1.22
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.51
#   eval: bucket 3 perplexity 2.56
# global step 14700 learning rate 0.3928 step-time 3.95 perplexity 1.31
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.38
#   eval: bucket 3 perplexity 2.37
# global step 14800 learning rate 0.3928 step-time 3.49 perplexity 1.23
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 2.60
# global step 14900 learning rate 0.3928 step-time 4.18 perplexity 1.29
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.44
#   eval: bucket 3 perplexity 2.83
# global step 15000 learning rate 0.3928 step-time 3.37 perplexity 1.18
#   eval: bucket 0 perplexity 1.01
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.37
#   eval: bucket 3 perplexity 2.35
# global step 15100 learning rate 0.3928 step-time 3.40 perplexity 1.18
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 2.47
# global step 15200 learning rate 0.3928 step-time 3.38 perplexity 1.21
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 2.82
# global step 15300 learning rate 0.3928 step-time 3.57 perplexity 1.20
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.37
#   eval: bucket 3 perplexity 2.58
# global step 15400 learning rate 0.3928 step-time 3.62 perplexity 1.19
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 2.36
# global step 15500 learning rate 0.3928 step-time 3.93 perplexity 1.30
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.50
#   eval: bucket 3 perplexity 2.30
# global step 15600 learning rate 0.3889 step-time 3.79 perplexity 1.22
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.40
#   eval: bucket 3 perplexity 2.37
# global step 15700 learning rate 0.3889 step-time 3.41 perplexity 1.17
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.35
#   eval: bucket 3 perplexity 2.47
# global step 15800 learning rate 0.3889 step-time 4.08 perplexity 1.26
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.45
#   eval: bucket 3 perplexity 2.36
# global step 15900 learning rate 0.3889 step-time 3.89 perplexity 1.22
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.44
#   eval: bucket 3 perplexity 2.84
# global step 16000 learning rate 0.3889 step-time 4.17 perplexity 1.22
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 2.61
# global step 16100 learning rate 0.3889 step-time 3.74 perplexity 1.16
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 2.32
# global step 16200 learning rate 0.3889 step-time 4.10 perplexity 1.25
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.38
#   eval: bucket 3 perplexity 2.38
# global step 16300 learning rate 0.3850 step-time 3.20 perplexity 1.14
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 2.53
# global step 16400 learning rate 0.3850 step-time 3.64 perplexity 1.19
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 2.38
# global step 16500 learning rate 0.3850 step-time 3.37 perplexity 1.15
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.38
#   eval: bucket 3 perplexity 2.23
# global step 16600 learning rate 0.3850 step-time 3.57 perplexity 1.17
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 2.55
# global step 16700 learning rate 0.3850 step-time 3.70 perplexity 1.18
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.36
#   eval: bucket 3 perplexity 2.37
# global step 16800 learning rate 0.3850 step-time 3.87 perplexity 1.26
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.36
#   eval: bucket 3 perplexity 2.72
# global step 16900 learning rate 0.3812 step-time 3.24 perplexity 1.15
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 2.23
# global step 17000 learning rate 0.3812 step-time 4.04 perplexity 1.25
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 2.40
# global step 17100 learning rate 0.3812 step-time 3.94 perplexity 1.20
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 2.36
# global step 17200 learning rate 0.3812 step-time 3.76 perplexity 1.20
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.43
#   eval: bucket 3 perplexity 2.73
# global step 17300 learning rate 0.3812 step-time 3.37 perplexity 1.15
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 2.49
# global step 17400 learning rate 0.3812 step-time 4.29 perplexity 1.28
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 2.07
# global step 17500 learning rate 0.3774 step-time 3.84 perplexity 1.19
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 2.20
# global step 17600 learning rate 0.3774 step-time 3.58 perplexity 1.16
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 2.32
# global step 17700 learning rate 0.3774 step-time 4.26 perplexity 1.28
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.35
#   eval: bucket 3 perplexity 2.30
# global step 17800 learning rate 0.3774 step-time 3.71 perplexity 1.17
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 2.68
# global step 17900 learning rate 0.3774 step-time 3.87 perplexity 1.19
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 2.36
# global step 18000 learning rate 0.3774 step-time 4.10 perplexity 1.24
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.36
#   eval: bucket 3 perplexity 2.26
# global step 18100 learning rate 0.3774 step-time 3.81 perplexity 1.16
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 2.66
# global step 18200 learning rate 0.3774 step-time 4.70 perplexity 1.29
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.40
#   eval: bucket 3 perplexity 2.42
# global step 18300 learning rate 0.3736 step-time 4.46 perplexity 1.21
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.37
#   eval: bucket 3 perplexity 2.48
# global step 18400 learning rate 0.3736 step-time 4.85 perplexity 1.19
#   eval: bucket 0 perplexity 1.01
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 2.13
# global step 18500 learning rate 0.3736 step-time 4.69 perplexity 1.17
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.97
# global step 18600 learning rate 0.3736 step-time 4.94 perplexity 1.23
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.51
#   eval: bucket 3 perplexity 2.34

# %% [markdown]
# ## Decode sentences

# %%
sess = tf.InteractiveSession()
model = create_model(sess, True, model_path, config=config)
# Out:
# Reading model parameters from /Users/atpaino/data/textcorrecter/dialog_corpus/dialog_correcter_model/translate.ckpt-18900

# %%
def dec(s, verbose=True):
    return decode(sess, model, data_reader, [s], verbose=verbose)

# %%
decoded = decode(sess, model, data_reader,
                 ["you must have girlfriend"])
# Out:
# Input: you must have girlfriend
# Output: you must have a girlfriend

# %%
data_reader.word_counts.most_common(100)
# Out:
# [('.', 273361),
#  (',', 134636),
#  ('you', 118454),
#  ('i', 113224),
#  ('?', 87731),
#  ('the', 78659),
#  ('to', 63891),
#  ('a', 56174),
#  ("'s", 53300),
#  ('it', 52322),
#  ("n't", 43814),
#  ('...', 40836),
#  ('do', 37389),
#  ('that', 37061),
#  ('and', 36616),
#  ('of', 31184),
#  ('!', 30120),
#  ('what', 29827),
#  ('in', 27239),
#  ('me', 25549),
#  ('is', 24971),
#  ('we', 23379),
#  ('--', 22434),
#  ('he', 21586),
#  ('this', 19597),
#  ('for', 18709),
#  ('have', 18202),
#  ("'m", 18166),
#  ("'re", 17478),
#  ('know', 17341),
#  ('was', 16955),
#  ('your', 16710),
#  ('my', 16560),
#  ('not', 15725),
#  ('be', 15485),
#  ('on', 15470),
#  ('no', 15220),
#  ('are', 14038),
#  ('with', 13742),
#  ('but', 13648),
#  ('they', 13433),
#  ('just', 12635),
#  ('all', 12204),
#  ('like', 11844),
#  ("'ll", 11798),
#  ('did', 11560),
#  ('there', 11543),
#  ('get', 11314),
#  ('about', 11179),
#  ('so', 10791),
#  ('out', 10648),
#  ('got', 10635),
#  ('here', 10524),
#  ('if', 10478),
#  ('she', 9736),
#  ('him', 9568),
#  ('can', 9401),
#  ('up', 9334),
#  ('how', 9116),
#  ('want', 8890),
#  ("'ve", 8703),
#  ('think', 8652),
#  ('at', 8529),
#  ('one', 8455),
#  ('right', 8114),
#  ('go', 8016),
#  ('well', 7875),
#  ('now', 7817),
#  ("'", 7441),
#  ('her', 7276),
#  ('why', 6956),
#  ('going', 6945),
#  ('who', 6659),
#  ('see', 6496),
#  ('would', 6465),
#  ('oh', 6318),
#  ('as', 6254),
#  ("'d", 5919),
#  ('yes', 5906),
#  ('yeah', 5773),
#  ('good', 5747),
#  ('his', 5705),
#  ('when', 5686),
#  ('could', 5673),
#  ('an', 5476),
#  ('tell', 5451),
#  ('where', 5433),
#  ('from', 5430),
#  ('were', 5366),
#  ('come', 5356),
#  ('time', 5301),
#  ('ca', 5275),
#  ('will', 5245),
#  ('or', 5210),
#  ('some', 5209),
#  ('been', 5177),
#  ('<', 5097),
#  ('>', 5095),
#  ('let', 4951),
#  ('back', 4927)]

# %%
# Build corpus and decode hypotheses.
baseline_hypotheses = defaultdict(list)  # The model's input
model_hypotheses = defaultdict(list)  # The actual model's predictions
targets = defaultdict(list)

for source, target in data_reader.read_words(test_path):
    
    matching_buckets = [i for i, bucket in enumerate(model.buckets) if len(source) < bucket[0]]
    if not matching_buckets:
        continue
    bucket_id = matching_buckets[0]
    
    model_hypotheses[bucket_id].append(dec(" ".join(source), verbose=False)[0])
    
    # Replace out of vocab words with "UNK" in the baseline hypothesis to make it a little fairer.
    baseline_hypothesis = [word if word in data_reader.word_to_id else MovieDialogReader.UNKNOWN_TOKEN
                           for word in source]
    baseline_hypotheses[bucket_id].append(baseline_hypothesis)
    
    # nltk.corpus_bleu expects a list of one or more reference tranlsations per sample,
    # so we wrap the target list in another list here.
    targets[bucket_id].append([target])

# %%
for bucket_id in targets.keys():
    baseline_bleu_score = nltk.translate.bleu_score.corpus_bleu(targets[bucket_id], baseline_hypotheses[bucket_id])
    model_bleu_score = nltk.translate.bleu_score.corpus_bleu(targets[bucket_id], model_hypotheses[bucket_id])
    print("Bucket {}: {}".format(bucket_id, model.buckets[bucket_id]))
    print("\tBaseline BLEU = {}\n\tModel BLEU = {}".format(baseline_bleu_score, model_bleu_score))
# Out:
# Bucket 0: (10, 10)
# 	Baseline BLEU = 0.747396876291
# 	Model BLEU = 0.690203743792
# Bucket 1: (15, 15)
# 	Baseline BLEU = 0.778185053349
# 	Model BLEU = 0.653820987905
# Bucket 2: (20, 20)
# 	Baseline BLEU = 0.806628147208
# 	Model BLEU = 0.576479857871
# Bucket 3: (40, 40)
# 	Baseline BLEU = 0.832271735442
# 	Model BLEU = 0.339813197828
