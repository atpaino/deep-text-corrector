# %%
from __future__ import print_function

import os
import time
import numpy as np
import tensorflow as tf
import pandas as pd
from collections import defaultdict

from sklearn.metrics import roc_auc_score, accuracy_score
import nltk

from correct_text import train, decode, create_model, DefaultConfig, DefaultMovieDialogConfig
from text_correcter_model import PTBDataReader, MovieDialogReader

# %matplotlib inline

# %%
root_data_path = "/Users/atpaino/data/textcorrecter/dialog_corpus"
train_path = os.path.join(root_data_path, "cleaned_dialog_train.txt")#"ptb.train.txt") 
val_path = os.path.join(root_data_path, "cleaned_dialog_val.txt")#"ptb.valid.txt")
test_path = os.path.join(root_data_path, "cleaned_dialog_test.txt")
model_path = os.path.join(root_data_path, "dialog_correcter_model")
config = DefaultConfig()

# %% [markdown]
# ## Train

# %%
data_reader = MovieDialogReader(config, train_path)

# %%
train(data_reader, train_path, val_path, model_path)
# Out:
# Reading data; train = /Users/atpaino/data/textcorrecter/dialog_corpus/cleaned_dialog_train.txt, test = /Users/atpaino/data/textcorrecter/dialog_corpus/cleaned_dialog_val.txt
# Creating 2 layers of 512 units.
# Reading model parameters from /Users/atpaino/data/textcorrecter/dialog_corpus/dialog_correcter_model/translate.ckpt-9600
# Training bucket sizes: [113333, 49032, 28362, 40252]
# Total train size: 230979.0
# global step 9700 learning rate 0.4432 step-time 3.69 perplexity 1.34
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.36
#   eval: bucket 2 perplexity 1.91
#   eval: bucket 3 perplexity 3.93
# global step 9800 learning rate 0.4432 step-time 4.00 perplexity 1.47
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.66
#   eval: bucket 3 perplexity 3.14
# global step 9900 learning rate 0.4432 step-time 4.28 perplexity 1.53
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.85
#   eval: bucket 3 perplexity 3.87
# global step 10000 learning rate 0.4432 step-time 4.35 perplexity 1.47
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.34
#   eval: bucket 2 perplexity 1.81
#   eval: bucket 3 perplexity 3.33
# global step 10100 learning rate 0.4432 step-time 4.46 perplexity 1.50
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.62
#   eval: bucket 3 perplexity 3.02
# global step 10200 learning rate 0.4432 step-time 4.06 perplexity 1.74
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.64
#   eval: bucket 3 perplexity 3.53
# global step 10300 learning rate 0.4388 step-time 3.58 perplexity 1.37
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.71
#   eval: bucket 3 perplexity 3.18
# global step 10400 learning rate 0.4388 step-time 4.02 perplexity 1.48
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.60
#   eval: bucket 3 perplexity 3.15
# global step 10500 learning rate 0.4388 step-time 3.68 perplexity 1.32
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.59
#   eval: bucket 3 perplexity 3.49
# global step 10600 learning rate 0.4388 step-time 4.16 perplexity 1.39
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.29
#   eval: bucket 2 perplexity 1.81
#   eval: bucket 3 perplexity 2.95
# global step 10700 learning rate 0.4388 step-time 3.86 perplexity 1.38
#   eval: bucket 0 perplexity 1.20
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.56
#   eval: bucket 3 perplexity 3.47
# global step 10800 learning rate 0.4388 step-time 3.53 perplexity 1.33
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.78
#   eval: bucket 3 perplexity 3.35
# global step 10900 learning rate 0.4388 step-time 3.61 perplexity 1.43
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.37
#   eval: bucket 2 perplexity 1.79
#   eval: bucket 3 perplexity 3.92
# global step 11000 learning rate 0.4344 step-time 4.26 perplexity 1.41
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.27
#   eval: bucket 2 perplexity 1.52
#   eval: bucket 3 perplexity 3.35
# global step 11100 learning rate 0.4344 step-time 3.77 perplexity 1.37
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.60
#   eval: bucket 3 perplexity 3.33
# global step 11200 learning rate 0.4344 step-time 4.01 perplexity 1.40
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.66
#   eval: bucket 3 perplexity 2.76
# global step 11300 learning rate 0.4344 step-time 3.51 perplexity 1.30
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.36
#   eval: bucket 2 perplexity 1.75
#   eval: bucket 3 perplexity 3.39
# global step 11400 learning rate 0.4344 step-time 4.17 perplexity 1.46
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.60
#   eval: bucket 3 perplexity 3.26
# global step 11500 learning rate 0.4300 step-time 3.63 perplexity 1.31
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.36
#   eval: bucket 2 perplexity 1.51
#   eval: bucket 3 perplexity 3.27
# global step 11600 learning rate 0.4300 step-time 3.45 perplexity 1.28
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.69
#   eval: bucket 3 perplexity 2.90
# global step 11700 learning rate 0.4300 step-time 3.41 perplexity 1.28
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.66
#   eval: bucket 3 perplexity 3.70
# global step 11800 learning rate 0.4300 step-time 3.64 perplexity 1.32
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.48
#   eval: bucket 2 perplexity 1.60
#   eval: bucket 3 perplexity 3.63
# global step 11900 learning rate 0.4257 step-time 3.74 perplexity 1.31
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.66
#   eval: bucket 3 perplexity 3.38
# global step 12000 learning rate 0.4257 step-time 3.90 perplexity 1.33
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.28
#   eval: bucket 2 perplexity 1.61
#   eval: bucket 3 perplexity 2.92
# global step 12100 learning rate 0.4215 step-time 3.66 perplexity 1.24
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.47
#   eval: bucket 3 perplexity 2.71
# global step 12200 learning rate 0.4215 step-time 3.41 perplexity 1.28
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.65
#   eval: bucket 3 perplexity 2.75
# global step 12300 learning rate 0.4215 step-time 3.67 perplexity 1.28
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.61
#   eval: bucket 3 perplexity 2.64
# global step 12400 learning rate 0.4215 step-time 3.46 perplexity 1.28
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.54
#   eval: bucket 2 perplexity 2.19
#   eval: bucket 3 perplexity 4.49
# global step 12500 learning rate 0.4215 step-time 3.62 perplexity 1.29
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.64
#   eval: bucket 3 perplexity 2.70
# global step 12600 learning rate 0.4173 step-time 4.31 perplexity 1.40
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.47
#   eval: bucket 3 perplexity 2.79
# global step 12700 learning rate 0.4131 step-time 3.95 perplexity 1.29
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.23
#   eval: bucket 2 perplexity 1.49
#   eval: bucket 3 perplexity 2.53
# global step 12800 learning rate 0.4131 step-time 3.61 perplexity 1.26
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 2.77
# global step 12900 learning rate 0.4131 step-time 3.33 perplexity 1.26
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.31
#   eval: bucket 2 perplexity 1.48
#   eval: bucket 3 perplexity 3.31
# global step 13000 learning rate 0.4131 step-time 4.39 perplexity 1.37
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.57
#   eval: bucket 3 perplexity 3.33
# global step 13100 learning rate 0.4090 step-time 4.16 perplexity 1.32
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.44
#   eval: bucket 3 perplexity 2.97
# global step 13200 learning rate 0.4090 step-time 3.95 perplexity 1.29
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.43
#   eval: bucket 3 perplexity 3.04
# global step 13300 learning rate 0.4090 step-time 3.12 perplexity 1.19
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.43
#   eval: bucket 3 perplexity 2.96
# global step 13400 learning rate 0.4090 step-time 3.49 perplexity 1.22
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.50
#   eval: bucket 3 perplexity 2.62
# global step 13500 learning rate 0.4090 step-time 3.84 perplexity 1.30
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.48
#   eval: bucket 3 perplexity 2.79
# global step 13600 learning rate 0.4049 step-time 3.99 perplexity 1.28
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.43
#   eval: bucket 3 perplexity 2.73
# global step 13700 learning rate 0.4049 step-time 3.08 perplexity 1.19
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.33
#   eval: bucket 2 perplexity 1.59
#   eval: bucket 3 perplexity 3.42
# global step 13800 learning rate 0.4049 step-time 3.85 perplexity 1.34
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.45
#   eval: bucket 3 perplexity 2.22
# global step 13900 learning rate 0.4008 step-time 3.56 perplexity 1.23
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.43
#   eval: bucket 3 perplexity 2.37
# global step 14000 learning rate 0.4008 step-time 3.48 perplexity 1.21
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.40
#   eval: bucket 3 perplexity 2.59
# global step 14100 learning rate 0.4008 step-time 3.88 perplexity 1.29
#   eval: bucket 0 perplexity 1.15
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.46
#   eval: bucket 3 perplexity 2.77
# global step 14200 learning rate 0.4008 step-time 3.87 perplexity 1.26
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.30
#   eval: bucket 2 perplexity 1.64
#   eval: bucket 3 perplexity 2.29
# global step 14300 learning rate 0.4008 step-time 3.23 perplexity 1.18
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.48
#   eval: bucket 3 perplexity 2.59
# global step 14400 learning rate 0.4008 step-time 3.32 perplexity 1.20
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.38
#   eval: bucket 3 perplexity 2.87
# global step 14500 learning rate 0.4008 step-time 3.64 perplexity 1.30
#   eval: bucket 0 perplexity 1.17
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.73
#   eval: bucket 3 perplexity 3.14
# global step 14600 learning rate 0.3968 step-time 4.06 perplexity 1.28
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.22
#   eval: bucket 2 perplexity 1.44
#   eval: bucket 3 perplexity 2.50
# global step 14700 learning rate 0.3968 step-time 3.26 perplexity 1.19
#   eval: bucket 0 perplexity 1.11
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.40
#   eval: bucket 3 perplexity 2.50
# global step 14800 learning rate 0.3968 step-time 3.79 perplexity 1.23
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 2.33
# global step 14900 learning rate 0.3968 step-time 3.55 perplexity 1.21
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.25
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 2.66
# global step 15000 learning rate 0.3968 step-time 3.78 perplexity 1.22
#   eval: bucket 0 perplexity 1.13
#   eval: bucket 1 perplexity 1.26
#   eval: bucket 2 perplexity 1.52
#   eval: bucket 3 perplexity 2.66
# global step 15100 learning rate 0.3968 step-time 3.35 perplexity 1.20
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 2.37
# global step 15200 learning rate 0.3968 step-time 4.29 perplexity 1.28
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.52
#   eval: bucket 3 perplexity 2.48
# global step 15300 learning rate 0.3928 step-time 3.43 perplexity 1.19
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 2.40
# global step 15400 learning rate 0.3928 step-time 3.88 perplexity 1.23
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 2.56
# global step 15500 learning rate 0.3928 step-time 4.02 perplexity 1.29
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.40
#   eval: bucket 3 perplexity 2.46
# global step 15600 learning rate 0.3889 step-time 3.29 perplexity 1.17
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.35
#   eval: bucket 3 perplexity 2.67
# global step 15700 learning rate 0.3889 step-time 3.69 perplexity 1.20
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 2.60
# global step 15800 learning rate 0.3889 step-time 3.57 perplexity 1.18
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.40
#   eval: bucket 3 perplexity 2.37
# global step 15900 learning rate 0.3889 step-time 3.53 perplexity 1.18
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.49
#   eval: bucket 3 perplexity 2.05
# global step 16000 learning rate 0.3889 step-time 3.74 perplexity 1.22
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.45
#   eval: bucket 3 perplexity 4.29
# global step 16100 learning rate 0.3850 step-time 4.02 perplexity 1.29
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.38
#   eval: bucket 3 perplexity 2.53
# global step 16200 learning rate 0.3812 step-time 3.40 perplexity 1.17
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 2.51
# global step 16300 learning rate 0.3812 step-time 3.59 perplexity 1.18
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 2.41
# global step 16400 learning rate 0.3812 step-time 3.55 perplexity 1.18
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 2.46
# global step 16500 learning rate 0.3812 step-time 3.56 perplexity 1.17
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 2.52
# global step 16600 learning rate 0.3812 step-time 3.42 perplexity 1.16
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.35
#   eval: bucket 3 perplexity 2.87
# global step 16700 learning rate 0.3812 step-time 3.66 perplexity 1.19
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.24
#   eval: bucket 2 perplexity 1.84
#   eval: bucket 3 perplexity 5.37
# global step 16800 learning rate 0.3774 step-time 4.00 perplexity 1.31
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.36
#   eval: bucket 3 perplexity 2.36
# global step 16900 learning rate 0.3736 step-time 3.81 perplexity 1.24
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 2.37
# global step 17000 learning rate 0.3736 step-time 3.74 perplexity 1.18
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 2.30
# global step 17100 learning rate 0.3736 step-time 3.66 perplexity 1.18
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.35
#   eval: bucket 3 perplexity 2.42
# global step 17200 learning rate 0.3736 step-time 3.80 perplexity 1.18
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 2.31
# global step 17300 learning rate 0.3736 step-time 3.68 perplexity 1.18
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 2.50
# global step 17400 learning rate 0.3736 step-time 4.22 perplexity 1.24
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 2.45
# global step 17500 learning rate 0.3699 step-time 3.65 perplexity 1.19
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.40
#   eval: bucket 2 perplexity 1.84
#   eval: bucket 3 perplexity 6.18
# global step 17600 learning rate 0.3699 step-time 3.15 perplexity 1.18
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.36
#   eval: bucket 3 perplexity 2.29
# global step 17700 learning rate 0.3699 step-time 3.92 perplexity 1.20
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 2.32
# global step 17800 learning rate 0.3699 step-time 3.57 perplexity 1.15
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 2.30
# global step 17900 learning rate 0.3699 step-time 3.65 perplexity 1.20
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.98
# global step 18000 learning rate 0.3662 step-time 3.81 perplexity 1.18
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 2.47
# global step 18100 learning rate 0.3662 step-time 3.64 perplexity 1.16
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 1.97
# global step 18200 learning rate 0.3662 step-time 3.36 perplexity 1.14
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.36
#   eval: bucket 3 perplexity 2.03
# global step 18300 learning rate 0.3662 step-time 3.81 perplexity 1.17
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 2.31
# global step 18400 learning rate 0.3662 step-time 3.89 perplexity 1.23
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.38
#   eval: bucket 3 perplexity 2.64
# global step 18500 learning rate 0.3625 step-time 4.43 perplexity 1.24
#   eval: bucket 0 perplexity 1.12
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 2.41
# global step 18600 learning rate 0.3589 step-time 3.73 perplexity 1.16
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 2.14
# global step 18700 learning rate 0.3589 step-time 3.26 perplexity 1.12
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.37
#   eval: bucket 3 perplexity 2.07
# global step 18800 learning rate 0.3589 step-time 3.68 perplexity 1.15
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.32
#   eval: bucket 3 perplexity 2.05
# global step 18900 learning rate 0.3589 step-time 4.29 perplexity 1.26
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 2.08
# global step 19000 learning rate 0.3553 step-time 3.33 perplexity 1.13
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 2.00
# global step 19100 learning rate 0.3553 step-time 4.03 perplexity 1.18
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 2.08
# global step 19200 learning rate 0.3553 step-time 3.65 perplexity 1.14
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.16
#   eval: bucket 2 perplexity 1.37
#   eval: bucket 3 perplexity 1.90
# global step 19300 learning rate 0.3553 step-time 3.17 perplexity 1.11
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.49
#   eval: bucket 3 perplexity 2.28
# global step 19400 learning rate 0.3553 step-time 2.96 perplexity 1.09
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.35
#   eval: bucket 3 perplexity 2.02
# global step 19500 learning rate 0.3553 step-time 4.06 perplexity 1.18
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 2.40
# global step 19600 learning rate 0.3517 step-time 3.83 perplexity 1.16
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.36
#   eval: bucket 3 perplexity 1.93
# global step 19700 learning rate 0.3517 step-time 3.92 perplexity 1.16
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.94
# global step 19800 learning rate 0.3517 step-time 3.28 perplexity 1.12
#   eval: bucket 0 perplexity 1.01
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 2.15
# global step 19900 learning rate 0.3517 step-time 3.89 perplexity 1.16
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.99
# global step 20000 learning rate 0.3517 step-time 4.37 perplexity 1.21
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 2.20
# global step 20100 learning rate 0.3482 step-time 3.45 perplexity 1.12
#   eval: bucket 0 perplexity 1.14
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 2.12
# global step 20200 learning rate 0.3482 step-time 3.54 perplexity 1.13
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 2.40
# global step 20300 learning rate 0.3482 step-time 3.93 perplexity 1.15
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.16
#   eval: bucket 3 perplexity 1.91
# global step 20400 learning rate 0.3482 step-time 3.50 perplexity 1.12
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 2.33
# global step 20500 learning rate 0.3482 step-time 3.99 perplexity 1.17
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.97
#   eval: bucket 3 perplexity 6.11
# global step 20600 learning rate 0.3447 step-time 3.53 perplexity 1.16
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 2.10
# global step 20700 learning rate 0.3447 step-time 3.40 perplexity 1.11
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 2.25
# global step 20800 learning rate 0.3447 step-time 3.25 perplexity 1.10
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.35
#   eval: bucket 3 perplexity 1.98
# global step 20900 learning rate 0.3447 step-time 3.24 perplexity 1.10
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.21
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 2.46
# global step 21000 learning rate 0.3447 step-time 3.33 perplexity 1.11
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.91
# global step 21100 learning rate 0.3447 step-time 3.99 perplexity 1.14
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.35
#   eval: bucket 3 perplexity 2.12
# global step 21200 learning rate 0.3413 step-time 3.87 perplexity 1.13
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 2.08
# global step 21300 learning rate 0.3413 step-time 3.47 perplexity 1.12
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.18
#   eval: bucket 2 perplexity 1.41
#   eval: bucket 3 perplexity 4.25
# global step 21400 learning rate 0.3413 step-time 3.32 perplexity 1.16
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.42
#   eval: bucket 3 perplexity 2.19
# global step 21500 learning rate 0.3379 step-time 3.96 perplexity 1.14
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 2.05
# global step 21600 learning rate 0.3379 step-time 3.57 perplexity 1.12
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.89
# global step 21700 learning rate 0.3379 step-time 3.90 perplexity 1.13
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 2.08
# global step 21800 learning rate 0.3379 step-time 3.69 perplexity 1.17
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 2.12
# global step 21900 learning rate 0.3345 step-time 3.51 perplexity 1.12
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.99
# global step 22000 learning rate 0.3345 step-time 3.72 perplexity 1.12
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 2.05
# global step 22100 learning rate 0.3345 step-time 3.83 perplexity 1.12
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.08
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.79
# global step 22200 learning rate 0.3345 step-time 3.55 perplexity 1.11
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.98
# global step 22300 learning rate 0.3345 step-time 4.04 perplexity 1.13
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 2.00
# global step 22400 learning rate 0.3311 step-time 3.51 perplexity 1.11
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 2.04
# global step 22500 learning rate 0.3311 step-time 3.32 perplexity 1.10
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.20
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.98
# global step 22600 learning rate 0.3311 step-time 3.27 perplexity 1.09
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.94
# global step 22700 learning rate 0.3311 step-time 3.67 perplexity 1.11
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 2.01
# global step 22800 learning rate 0.3278 step-time 3.66 perplexity 1.11
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 2.04
# global step 22900 learning rate 0.3278 step-time 3.51 perplexity 1.10
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 2.05
# global step 23000 learning rate 0.3278 step-time 3.61 perplexity 1.10
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 2.03
# global step 23100 learning rate 0.3278 step-time 3.71 perplexity 1.11
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.89
# global step 23200 learning rate 0.3246 step-time 4.06 perplexity 1.20
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.33
#   eval: bucket 3 perplexity 2.31
# global step 23300 learning rate 0.3213 step-time 3.66 perplexity 1.11
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.17
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.94
# global step 23400 learning rate 0.3213 step-time 3.51 perplexity 1.11
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 2.04
# global step 23500 learning rate 0.3213 step-time 4.25 perplexity 1.15
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 2.23
# global step 23600 learning rate 0.3213 step-time 3.67 perplexity 1.11
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.97
# global step 23700 learning rate 0.3213 step-time 4.15 perplexity 1.13
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 2.19
# global step 23800 learning rate 0.3213 step-time 3.75 perplexity 1.10
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 1.82
# global step 23900 learning rate 0.3213 step-time 4.06 perplexity 1.13
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.07
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 2.12
# global step 24000 learning rate 0.3213 step-time 3.95 perplexity 1.11
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.95
# global step 24100 learning rate 0.3213 step-time 4.04 perplexity 1.12
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.94
# global step 24200 learning rate 0.3213 step-time 3.22 perplexity 1.08
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 2.01
# global step 24300 learning rate 0.3213 step-time 4.16 perplexity 1.12
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.76
# global step 24400 learning rate 0.3213 step-time 3.78 perplexity 1.10
#   eval: bucket 0 perplexity 1.01
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 2.03
# global step 24500 learning rate 0.3213 step-time 3.95 perplexity 1.16
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.32
#   eval: bucket 2 perplexity 1.78
#   eval: bucket 3 perplexity 4.77
# global step 24600 learning rate 0.3181 step-time 3.63 perplexity 1.14
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 2.10
# global step 24700 learning rate 0.3181 step-time 3.72 perplexity 1.10
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.19
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.81
# global step 24800 learning rate 0.3181 step-time 3.52 perplexity 1.09
#   eval: bucket 0 perplexity 1.16
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.84
# global step 24900 learning rate 0.3181 step-time 3.75 perplexity 1.10
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.07
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.99
# global step 25000 learning rate 0.3181 step-time 3.96 perplexity 1.13
#   eval: bucket 0 perplexity 1.01
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 2.06
# global step 25100 learning rate 0.3149 step-time 3.44 perplexity 1.08
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 2.00
# global step 25200 learning rate 0.3149 step-time 4.20 perplexity 1.12
#   eval: bucket 0 perplexity 1.10
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.39
#   eval: bucket 3 perplexity 1.87
# global step 25300 learning rate 0.3149 step-time 3.67 perplexity 1.10
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 2.00
# global step 25400 learning rate 0.3149 step-time 3.93 perplexity 1.11
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.88
# global step 25500 learning rate 0.3149 step-time 3.86 perplexity 1.10
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.79
# global step 25600 learning rate 0.3149 step-time 3.58 perplexity 1.09
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.69
# global step 25700 learning rate 0.3149 step-time 3.73 perplexity 1.09
#   eval: bucket 0 perplexity 1.01
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.93
# global step 25800 learning rate 0.3149 step-time 3.93 perplexity 1.10
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.81
# global step 25900 learning rate 0.3118 step-time 4.09 perplexity 1.10
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.66
# global step 26000 learning rate 0.3086 step-time 3.83 perplexity 1.10
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.91
# global step 26100 learning rate 0.3086 step-time 3.90 perplexity 1.11
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.27
#   eval: bucket 3 perplexity 1.94
# global step 26200 learning rate 0.3056 step-time 4.03 perplexity 1.10
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.88
# global step 26300 learning rate 0.3056 step-time 3.99 perplexity 1.10
#   eval: bucket 0 perplexity 1.01
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.15
#   eval: bucket 3 perplexity 1.87
# global step 26400 learning rate 0.3056 step-time 3.32 perplexity 1.07
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.08
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 1.76
# global step 26500 learning rate 0.3056 step-time 3.81 perplexity 1.09
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.93
# global step 26600 learning rate 0.3056 step-time 3.66 perplexity 1.09
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.85
# global step 26700 learning rate 0.3056 step-time 3.79 perplexity 1.09
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 2.02
# global step 26800 learning rate 0.3056 step-time 4.08 perplexity 1.11
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.95
# global step 26900 learning rate 0.3025 step-time 3.86 perplexity 1.10
#   eval: bucket 0 perplexity 1.01
#   eval: bucket 1 perplexity 1.12
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.78
# global step 27000 learning rate 0.3025 step-time 3.62 perplexity 1.09
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.29
#   eval: bucket 3 perplexity 1.68
# global step 27100 learning rate 0.3025 step-time 3.85 perplexity 1.09
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 1.66
# global step 27200 learning rate 0.3025 step-time 3.87 perplexity 1.09
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.06
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.86
# global step 27300 learning rate 0.3025 step-time 3.45 perplexity 1.07
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.88
# global step 27400 learning rate 0.3025 step-time 4.03 perplexity 1.10
#   eval: bucket 0 perplexity 1.02
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 2.74
# global step 27500 learning rate 0.2995 step-time 3.76 perplexity 1.09
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.19
#   eval: bucket 3 perplexity 1.93
# global step 27600 learning rate 0.2995 step-time 3.37 perplexity 1.07
#   eval: bucket 0 perplexity 1.09
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 2.10
# global step 27700 learning rate 0.2995 step-time 3.86 perplexity 1.09
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.88
# global step 27800 learning rate 0.2995 step-time 3.14 perplexity 1.06
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.26
#   eval: bucket 3 perplexity 1.84
# global step 27900 learning rate 0.2995 step-time 4.08 perplexity 1.10
#   eval: bucket 0 perplexity 1.01
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.90
# global step 28000 learning rate 0.2965 step-time 3.95 perplexity 1.09
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.21
#   eval: bucket 3 perplexity 1.69
# global step 28100 learning rate 0.2965 step-time 3.85 perplexity 1.09
#   eval: bucket 0 perplexity 1.07
#   eval: bucket 1 perplexity 1.08
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.95
# global step 28200 learning rate 0.2965 step-time 4.15 perplexity 1.15
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.25
#   eval: bucket 3 perplexity 2.03
# global step 28300 learning rate 0.2935 step-time 3.90 perplexity 1.09
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.24
#   eval: bucket 3 perplexity 1.89
# global step 28400 learning rate 0.2935 step-time 3.79 perplexity 1.09
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.08
#   eval: bucket 2 perplexity 1.23
#   eval: bucket 3 perplexity 1.73
# global step 28500 learning rate 0.2935 step-time 4.14 perplexity 1.10
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.10
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.81
# global step 28600 learning rate 0.2935 step-time 3.74 perplexity 1.08
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.08
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.69
# global step 28700 learning rate 0.2935 step-time 4.11 perplexity 1.12
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.13
#   eval: bucket 2 perplexity 1.31
#   eval: bucket 3 perplexity 1.86
# global step 28800 learning rate 0.2906 step-time 3.86 perplexity 1.09
#   eval: bucket 0 perplexity 1.08
#   eval: bucket 1 perplexity 1.07
#   eval: bucket 2 perplexity 1.18
#   eval: bucket 3 perplexity 1.90
# global step 28900 learning rate 0.2906 step-time 3.36 perplexity 1.06
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.07
#   eval: bucket 2 perplexity 1.22
#   eval: bucket 3 perplexity 1.82
# global step 29000 learning rate 0.2906 step-time 3.69 perplexity 1.08
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.34
#   eval: bucket 3 perplexity 1.83
# global step 29100 learning rate 0.2906 step-time 4.24 perplexity 1.10
#   eval: bucket 0 perplexity 1.06
#   eval: bucket 1 perplexity 1.14
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.70
# global step 29200 learning rate 0.2877 step-time 3.78 perplexity 1.08
#   eval: bucket 0 perplexity 1.01
#   eval: bucket 1 perplexity 1.09
#   eval: bucket 2 perplexity 1.28
#   eval: bucket 3 perplexity 1.87
# global step 29300 learning rate 0.2877 step-time 3.87 perplexity 1.08
#   eval: bucket 0 perplexity 1.03
#   eval: bucket 1 perplexity 1.06
#   eval: bucket 2 perplexity 1.20
#   eval: bucket 3 perplexity 2.26
# global step 29400 learning rate 0.2877 step-time 3.64 perplexity 1.07
#   eval: bucket 0 perplexity 1.05
#   eval: bucket 1 perplexity 1.15
#   eval: bucket 2 perplexity 1.30
#   eval: bucket 3 perplexity 1.57
# global step 29500 learning rate 0.2877 step-time 3.86 perplexity 1.08
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.82
# global step 29600 learning rate 0.2877 step-time 3.53 perplexity 1.07
#   eval: bucket 0 perplexity 1.04
#   eval: bucket 1 perplexity 1.11
#   eval: bucket 2 perplexity 1.17
#   eval: bucket 3 perplexity 1.79

# %% [markdown]
# ## Decode sentences

# %%
data_reader = MovieDialogReader(config, train_path)

# %%
sess = tf.InteractiveSession()
model = create_model(sess, True, model_path, config=config)
# Out:
# Reading model parameters from /Users/atpaino/data/textcorrecter/dialog_corpus/dialog_correcter_model/translate.ckpt-29600

# %%
def dec(s, verbose=True):
    return decode(sess, model, data_reader, [s], verbose=verbose)

# %%
decoded = decode(sess, model, data_reader,
                 ["you must have girlfriend"])
# Out:
# Input: you must have girlfriend
# Output: you must have a girlfriend

# %%
data_reader.word_counts.most_common(100)
# Out:
# [('.', 273361),
#  (',', 134636),
#  ('you', 118454),
#  ('i', 113224),
#  ('?', 87731),
#  ('the', 78659),
#  ('to', 63891),
#  ('a', 56174),
#  ("'s", 53300),
#  ('it', 52322),
#  ("n't", 43814),
#  ('...', 40836),
#  ('do', 37389),
#  ('that', 37061),
#  ('and', 36616),
#  ('of', 31184),
#  ('!', 30120),
#  ('what', 29827),
#  ('in', 27239),
#  ('me', 25549),
#  ('is', 24971),
#  ('we', 23379),
#  ('--', 22434),
#  ('he', 21586),
#  ('this', 19597),
#  ('for', 18709),
#  ('have', 18202),
#  ("'m", 18166),
#  ("'re", 17478),
#  ('know', 17341),
#  ('was', 16955),
#  ('your', 16710),
#  ('my', 16560),
#  ('not', 15725),
#  ('be', 15485),
#  ('on', 15470),
#  ('no', 15220),
#  ('are', 14038),
#  ('with', 13742),
#  ('but', 13648),
#  ('they', 13433),
#  ('just', 12635),
#  ('all', 12204),
#  ('like', 11844),
#  ("'ll", 11798),
#  ('did', 11560),
#  ('there', 11543),
#  ('get', 11314),
#  ('about', 11179),
#  ('so', 10791),
#  ('out', 10648),
#  ('got', 10635),
#  ('here', 10524),
#  ('if', 10478),
#  ('she', 9736),
#  ('him', 9568),
#  ('can', 9401),
#  ('up', 9334),
#  ('how', 9116),
#  ('want', 8890),
#  ("'ve", 8703),
#  ('think', 8652),
#  ('at', 8529),
#  ('one', 8455),
#  ('right', 8114),
#  ('go', 8016),
#  ('well', 7875),
#  ('now', 7817),
#  ("'", 7441),
#  ('her', 7276),
#  ('why', 6956),
#  ('going', 6945),
#  ('who', 6659),
#  ('see', 6496),
#  ('would', 6465),
#  ('oh', 6318),
#  ('as', 6254),
#  ("'d", 5919),
#  ('yes', 5906),
#  ('yeah', 5773),
#  ('good', 5747),
#  ('his', 5705),
#  ('when', 5686),
#  ('could', 5673),
#  ('an', 5476),
#  ('tell', 5451),
#  ('where', 5433),
#  ('from', 5430),
#  ('were', 5366),
#  ('come', 5356),
#  ('time', 5301),
#  ('ca', 5275),
#  ('will', 5245),
#  ('or', 5210),
#  ('some', 5209),
#  ('been', 5177),
#  ('<', 5097),
#  ('>', 5095),
#  ('let', 4951),
#  ('back', 4927)]

# %%
# Build corpus and decode hypotheses.
baseline_hypotheses = defaultdict(list)  # The model's input
model_hypotheses = defaultdict(list)  # The actual model's predictions
targets = defaultdict(list)

for source, target in data_reader.read_words(test_path):
    
    matching_buckets = [i for i, bucket in enumerate(model.buckets) if len(source) < bucket[0]]
    if not matching_buckets:
        continue
    bucket_id = matching_buckets[0]
    
    model_hypotheses[bucket_id].append(dec(" ".join(source), verbose=False)[0])
    
    # Replace out of vocab words with "UNK" in the baseline hypothesis to make it a little fairer.
    baseline_hypothesis = [word if word in data_reader.word_to_id else MovieDialogReader.UNKNOWN_TOKEN
                           for word in source]
    baseline_hypotheses[bucket_id].append(baseline_hypothesis)
    
    # nltk.corpus_bleu expects a list of one or more reference tranlsations per sample,
    # so we wrap the target list in another list here.
    targets[bucket_id].append([target])

# %%
for bucket_id in targets.keys():
    baseline_bleu_score = nltk.translate.bleu_score.corpus_bleu(targets[bucket_id], baseline_hypotheses[bucket_id])
    model_bleu_score = nltk.translate.bleu_score.corpus_bleu(targets[bucket_id], model_hypotheses[bucket_id])
    print("Bucket {}: {}".format(bucket_id, model.buckets[bucket_id]))
    print("\tBaseline BLEU = {}\n\tModel BLEU = {}".format(baseline_bleu_score, model_bleu_score))
# Out:
# Bucket 0: (10, 10)
# 	Baseline BLEU = 0.729638310326
# 	Model BLEU = 0.695741131167
# Bucket 1: (15, 15)
# 	Baseline BLEU = 0.769472470187
# 	Model BLEU = 0.678890611587
# Bucket 2: (20, 20)
# 	Baseline BLEU = 0.798002323422
# 	Model BLEU = 0.621063999468
# Bucket 3: (40, 40)
# 	Baseline BLEU = 0.822407479385
# 	Model BLEU = 0.386759652473
